# %% [markdown]
# # Machine Learning Project in Gold Mining: How to maximize a gold recovery from an ore? (2022)

# %% [markdown]
# ## Research Question
# **How to maximize output from a gold reserve?**
#
# ## Project objective
# **To prepare a machine learning prototype model for predicting a coefficient of recovery of gold from the ore in order to find a solution to overcome the challenges of declining ore grades, remove parameters, which do not help increase the gold recovery, and to keep gold mining economically viable.**
#
# ## Data provided:
# **Gold mining and ore cleaning parameters.**
#
# ## Project Methodology
#
# 1)	Data preprocessing, cleaning for further analysis.
#
# 2)	Exploratory data analysis.
#
# 3)	Machine learning modelling, choosing the best model with most suitable hyperparameters, which is able to predict a continuous variable of a coefficient of gold recovery from the ore.
#
# 4)	Make conclusions and recommendations for business, which parameters influence the gold recovery most and should be considered more carefully in the technological process.

# %% [markdown]
# <h1>Content<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Opening-the-datasets" data-toc-modified-id="Opening-the-datasets-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Opening the datasets</a></span></li><li><span><a href="#Missing-valies:-Choosing-a-replacement-strategy" data-toc-modified-id="Missing-valies:-Choosing-a-replacement-strategy-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Missing valies: Choosing a replacement strategy</a></span></li><li><span><a href="#Поиск-дубликатов-в-данных" data-toc-modified-id="Поиск-дубликатов-в-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Поиск дубликатов в данных</a></span></li><li><span><a href="#Формирование-трех-новых-датасетов-на-основе-очищенных" data-toc-modified-id="Формирование-трех-новых-датасетов-на-основе-очищенных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Формирование трех новых датасетов на основе очищенных</a></span></li><li><span><a href="#Удалим-признаки-из-обучающей-выборки" data-toc-modified-id="Удалим-признаки-из-обучающей-выборки-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Удалим признаки из обучающей выборки</a></span></li><li><span><a href="#Добавим-в-исходные-тестовые-данные-test-data-целевые-признаки-final.output.recovery,-rougher.output.recovery-из-полных-данных" data-toc-modified-id="Добавим-в-исходные-тестовые-данные-test-data-целевые-признаки-final.output.recovery,-rougher.output.recovery-из-полных-данных-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Добавим в исходные тестовые данные test data целевые признаки final.output.recovery, rougher.output.recovery из полных данных</a></span></li><li><span><a href="#Проверим,-что-эффективность-обогащения-рассчитана-верно" data-toc-modified-id="Проверим,-что-эффективность-обогащения-рассчитана-верно-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Проверим, что эффективность обогащения рассчитана верно</a></span></li><li><span><a href="#Изучим-целевые-значения-в-df_train-датасете,-который-будет-использован-для-моделирования" data-toc-modified-id="Изучим-целевые-значения-в-df_train-датасете,-который-будет-использован-для-моделирования-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Изучим целевые значения в df_train датасете, который будет использован для моделирования</a></span></li><li><span><a href="#Избавимся-от-выбросов-в-целевых-показателях-датасета,-на-котором-будем-проводить-обучение" data-toc-modified-id="Избавимся-от-выбросов-в-целевых-показателях-датасета,-на-котором-будем-проводить-обучение-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Избавимся от выбросов в целевых показателях датасета, на котором будем проводить обучение</a></span></li><li><span><a href="#Проверим-выбросы-и-описательные-статистики-для-тестового-датасета" data-toc-modified-id="Проверим-выбросы-и-описательные-статистики-для-тестового-датасета-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Проверим выбросы и описательные статистики для тестового датасета</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Посмотрим,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки." data-toc-modified-id="Посмотрим,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки.</a></span></li><li><span><a href="#Сравним-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-Если-распределения-сильно-отличаются-друг-от-друга,-оценка-модели-будет-неправильной." data-toc-modified-id="Сравним-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-Если-распределения-сильно-отличаются-друг-от-друга,-оценка-модели-будет-неправильной.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Сравним распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.</a></span></li><li><span><a href="#Различия-распределения-целевых-признаков" data-toc-modified-id="Различия-распределения-целевых-признаков-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Различия распределения целевых признаков</a></span></li><li><span><a href="#Исследуем-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах." data-toc-modified-id="Исследуем-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах.-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.</a></span><ul class="toc-item"><li><span><a href="#Изучим-датасет-с-обучающими-данными,-который-планируем-использовать-для-обучения-модели." data-toc-modified-id="Изучим-датасет-с-обучающими-данными,-который-планируем-использовать-для-обучения-модели.-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Изучим датасет с <em>обучающими</em> данными, который планируем использовать для обучения модели.</a></span></li><li><span><a href="#Изучим-тестовый-датасет,-который-планируем-использовать-для-тестирования-модели." data-toc-modified-id="Изучим-тестовый-датасет,-который-планируем-использовать-для-тестирования-модели.-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Изучим <em>тестовый</em> датасет, который планируем использовать для тестирования модели.</a></span></li></ul></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Напишем-функцию-для-вычисления-итоговой-sMAPE." data-toc-modified-id="Напишем-функцию-для-вычисления-итоговой-sMAPE.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Напишем функцию для вычисления итоговой sMAPE.</a></span></li><li><span><a href="#Напишем-функцию-для-проверки-модели-кросс-валидацией" data-toc-modified-id="Напишем-функцию-для-проверки-модели-кросс-валидацией-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Напишем функцию для проверки модели кросс-валидацией</a></span></li><li><span><a href="#Создадим-функцию-для-автоматического-вывода-smape-каждого-этапа-и-финальной-sMAPE" data-toc-modified-id="Создадим-функцию-для-автоматического-вывода-smape-каждого-этапа-и-финальной-sMAPE-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Создадим функцию для автоматического вывода smape каждого этапа и финальной sMAPE</a></span></li><li><span><a href="#Обучим-разные-модели-и-оценим-их-качество-кросс-валидацией.-Выберем-лучшую-модель-и-проверим-её-на-тестовой-выборке." data-toc-modified-id="Обучим-разные-модели-и-оценим-их-качество-кросс-валидацией.-Выберем-лучшую-модель-и-проверим-её-на-тестовой-выборке.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Обучим разные модели и оценим их качество кросс-валидацией. Выберем лучшую модель и проверим её на тестовой выборке.</a></span><ul class="toc-item"><li><span><a href="#Подготовим-обучающие-выборки---признаки-и-целевые-признаки---для-этапа-флотации-и-финального-этапа-очистки" data-toc-modified-id="Подготовим-обучающие-выборки---признаки-и-целевые-признаки---для-этапа-флотации-и-финального-этапа-очистки-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Подготовим обучающие выборки - признаки и целевые признаки - для этапа <em>флотации</em> и <em>финального</em> этапа очистки</a></span></li></ul></li><li><span><a href="#Строим-модели-для-данных-при-флотации" data-toc-modified-id="Строим-модели-для-данных-при-флотации-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Строим модели для данных при <strong><em>флотации</em></strong></a></span><ul class="toc-item"><li><span><a href="#Проведем-масштабирование-признаков-на-этапе-флотации" data-toc-modified-id="Проведем-масштабирование-признаков-на-этапе-флотации-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Проведем масштабирование признаков на этапе флотации</a></span></li><li><span><a href="#Обучим-модели" data-toc-modified-id="Обучим-модели-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>Обучим модели</a></span></li><li><span><a href="#Обучим-модель-и-выполним-предсказания-на-тестовых-данных" data-toc-modified-id="Обучим-модель-и-выполним-предсказания-на-тестовых-данных-3.5.3"><span class="toc-item-num">3.5.3&nbsp;&nbsp;</span>Обучим модель и выполним предсказания на тестовых данных</a></span></li><li><span><a href="#Определим,-какие-из-признаков-больше-всего-влияют-на-целевые-признаки" data-toc-modified-id="Определим,-какие-из-признаков-больше-всего-влияют-на-целевые-признаки-3.5.4"><span class="toc-item-num">3.5.4&nbsp;&nbsp;</span>Определим, какие из признаков больше всего влияют на целевые признаки</a></span></li></ul></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Technological process
#
# ***Флотация***
#
# Во флотационную установку подаётся смесь золотосодержащей руды. После обогащения получается черновой концентрат и «отвальные хвосты», то есть остатки продукта с низкой концентрацией ценных металлов. На стабильность этого процесса влияет непостоянное и неоптимальное физико-химическое состояние флотационной пульпы (смеси твёрдых частиц и жидкости).
#
# ***Очистка***
#
# Черновой концентрат проходит две очистки. На выходе получается финальный концентрат и новые отвальные хвосты.

# %% [markdown]
# # Variables Description
#
# **Technological process**
#
# - Rougher feed — исходное сырье
# - Rougher additions (или reagent additions) — флотационные реагенты:
#         - Xanthate, Sulphate, Depressant
#         - Xanthate ксантогенат (промотер, или активатор флотации);
#         - Sulphate — сульфат (на данном производстве сульфид натрия);
#         - Depressant — депрессант (силикат натрия).
#
# - Rougher process (англ. «грубый процесс») — флотация
# - Rougher tails — отвальные хвосты
# - Float banks — флотационная установка
# - Cleaner process — очистка
# - Rougher Au — черновой концентрат золота
# - Final Au — финальный концентрат золота
#
# **Technological Stages Parameters**
#
# - air amount — объём воздуха
# - fluid levels — уровень жидкости
# - feed size — размер гранул сырья
# - feed rate — скорость подачи

# %% [markdown]
# # Features and targets naming
#
# Наименование признаков должно быть такое:
#
# **[этап].[тип_параметра].[название_параметра]**
#
# ***Пример: rougher.input.feed_ag***
#
# **Возможные значения для блока [этап]:**
# - _rougher_ — флотация
# - _primary_cleaner_ — первичная очистка
# - _secondary_cleaner_ — вторичная очистка
# - _final_ — финальные характеристики
#
# **Возможные значения для блока [тип_параметра]:**
# - _input_ — параметры сырья
# - _output_ — параметры продукта
# - _state_ — параметры, характеризующие текущее состояние этапа
# - _calculation_ — расчётные характеристики

# %% [markdown]
# # Расчёт эффективности
#
# **Нужно смоделировать процесс восстановления золота из золотосодержащей руды.**
#
# Эффективность обогащения рассчитывается по формуле:
#
#  ![image-2.png](attachment:image-2.png)
#
# где:
#
# - C — доля золота в концентрате после флотации/очистки;
# - F — доля золота в сырье/концентрате до флотации/очистки;
# - T — доля золота в отвальных хвостах после флотации/очистки.
#
#
# Для прогноза коэффициента нужно найти долю золота в концентратах и хвостах. Причём важен не только финальный продукт, но и черновой концентрат.

# %% [markdown]
# # Quality Metrics
#
# **Для решения задачи введём новую метрику качества — sMAPE (англ. Symmetric Mean Absolute Percentage Error, «симметричное среднее абсолютное процентное отклонение»).**
#
# Она похожа на MAE, но выражается не в абсолютных величинах, а в относительных. Почему симметричная? Она одинаково учитывает масштаб и целевого признака, и предсказания.
#
# **Метрика sMAPE вычисляется так:**
#  ![image-7.png](attachment:image-7.png)
#
#
# Обозначения:
#  ![image-6.png](attachment:image-6.png)
#
# - Значение целевого признака для объекта с порядковым номером i в выборке, на которой измеряется качество.
#  ![image-5.png](attachment:image-5.png)
#
# - Значение предсказания для объекта с порядковым номером i, например, в тестовой выборке.
#  ![image-4.png](attachment:image-4.png)
#
# - **Количество объектов в выборке**
#  ![image-3.png](attachment:image-3.png)
#
# - Суммирование по всем объектам выборки (i меняется от 1 до N).
#
# Нужно спрогнозировать сразу две величины:
#
# 1.	эффективность обогащения чернового концентрата rougher.output.recovery;
# 2.	эффективность обогащения финального концентрата final.output.recovery.
#
# Итоговая метрика складывается из двух величин:
#  ![image-2.png](attachment:image-2.png)

# %%
pip install plotly --upgrade
# Out:
# Requirement already satisfied: plotly in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (5.10.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from plotly) (8.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set()

import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter("ignore", category=RuntimeWarning)
pd.options.mode.chained_assignment = None 

from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.utils import shuffle

from scipy import stats as st # для доверительного интервала
from sklearn.model_selection import cross_val_score

import plotly.express as px
import plotly.graph_objects as go

from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler

# %%
pip install mglearn
# Out:
# Collecting mglearn
#   Using cached mglearn-0.1.9.tar.gz (540 kB)
# Requirement already satisfied: numpy in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from mglearn) (1.20.3)
# Requirement already satisfied: matplotlib in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from mglearn) (3.4.3)
# Requirement already satisfied: scikit-learn in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from mglearn) (0.24.2)
# Requirement already satisfied: pandas in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from mglearn) (1.3.4)
# Requirement already satisfied: pillow in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from mglearn) (8.4.0)
# Requirement already satisfied: cycler in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from mglearn) (0.10.0)
# Requirement already satisfied: imageio in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from mglearn) (2.9.0)
# Requirement already satisfied: joblib in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from mglearn) (1.1.0)
# Requirement already satisfied: six in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from cycler->mglearn) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->mglearn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->mglearn) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->mglearn) (3.0.4)
# Requirement already satisfied: pytz>=2017.3 in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from pandas->mglearn) (2021.3)
# Requirement already satisfied: scipy>=0.19.1 in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->mglearn) (1.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->mglearn) (2.2.0)
# Building wheels for collected packages: mglearn
#   Building wheel for mglearn (setup.py) ... done
#   Created wheel for mglearn: filename=mglearn-0.1.9-py2.py3-none-any.whl size=582637 sha256=d26e9cd85b88aedb258b4cf188523c5af25178de54833fe83c2668ac349e0208
#   Stored in directory: /Users/yuliabezginova/Library/Caches/pip/wheels/df/30/8a/1e2c8f144c9d411b0688f628d496d2db8f61b6d14bcedaa1df
# Successfully built mglearn
# Installing collected packages: mglearn
# Successfully installed mglearn-0.1.9
# Note: you may need to restart the kernel to use updated packages.

# %%
import mglearn

# %% [markdown]
# ## 1. Data preprocessing

# %% [markdown]
# ### 1.1 Opening the datasets

# %%
train_data = pd.read_csv('/Users/yuliabezginova/PycharmProjects/04_ML_GoldMining_ToMaximizeAGoldRecoveryFromOre/gold_recovery_train_new.csv')

# %%
test_data = pd.read_csv('/Users/yuliabezginova/PycharmProjects/04_ML_GoldMining_ToMaximizeAGoldRecoveryFromOre/gold_recovery_test_new.csv')

# %%
full_data = pd.read_csv('/Users/yuliabezginova/PycharmProjects/04_ML_GoldMining_ToMaximizeAGoldRecoveryFromOre/gold_recovery_full_new.csv')

# %%
display(train_data.head())
display(test_data.head())
display(full_data.head())
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# 2                    42.657501              68.116445             10.507046
# 3                    42.689819              68.347543             10.422762
# 4                    42.774141              66.927016             10.360302
#
#    final.output.tail_pb  final.output.tail_sol  final.output.tail_au  ...  \
# 0              0.895447              16.904297              2.143149  ...
# 1              0.927452              16.634514              2.224930  ...
# 2              0.953716              16.208849              2.257889  ...
# 3              0.883763              16.532835              2.146849  ...
# 4              0.792826              16.525686              2.055292  ...
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 14.016835
# 1                                 13.992281
# 2                                 14.015015
# 3                                 14.036510
# 4                                 14.027298
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -502.488007
# 1                                 -505.503262
# 2                                 -502.520901
# 3                                 -500.857308
# 4                                 -499.838632
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                 12.099931
# 1                                 11.950531
# 2                                 11.912783
# 3                                 11.999550
# 4                                 11.953070
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -504.715942
# 1                                 -501.331529
# 2                                 -501.133383
# 3                                 -501.193686
# 4                                 -501.053894
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                  9.925633
# 1                                 10.039245
# 2                                 10.070913
# 3                                  9.970366
# 4                                  9.925709
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -498.310211
# 1                                 -500.169983
# 2                                 -500.129135
# 3                                 -499.201640
# 4                                 -501.686727
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                  8.079666
# 1                                  7.984757
# 2                                  8.013877
# 3                                  7.977324
# 4                                  7.894242
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.470978
# 1                                 -500.582168
# 2                                 -500.517572
# 3                                 -500.255908
# 4                                 -500.356035
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 14.151341
# 1                                 13.998353
# 2                                 14.028663
# 3                                 14.005551
# 4                                 13.996647
#
#    secondary_cleaner.state.floatbank6_a_level
# 0                                 -605.841980
# 1                                 -599.787184
# 2                                 -601.427363
# 3                                 -599.996129
# 4                                 -601.496691
#
# [5 rows x 87 columns]
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# 1                        0.990469                             1398.777912
# 2                        0.996043                             1398.493666
# 3                        0.863514                             1399.618111
# 4                        0.805575                             1401.268123
#
#    primary_cleaner.state.floatbank8_a_level  \
# 0                               -500.225577
# 1                               -500.057435
# 2                               -500.868360
# 3                               -498.863574
# 4                               -500.808305
#
#    primary_cleaner.state.floatbank8_b_air  \
# 0                             1399.144926
# 1                             1398.055362
# 2                             1398.860436
# 3                             1397.440120
# 4                             1398.128818
#
#    primary_cleaner.state.floatbank8_b_level  \
# 0                               -499.919735
# 1                               -499.778182
# 2                               -499.764529
# 3                               -499.211024
# 4                               -499.504543
#
#    primary_cleaner.state.floatbank8_c_air  ...  \
# 0                             1400.102998  ...
# 1                             1396.151033  ...
# 2                             1398.075709  ...
# 3                             1400.129303  ...
# 4                             1402.172226  ...
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 12.023554
# 1                                 12.058140
# 2                                 11.962366
# 3                                 12.033091
# 4                                 12.025367
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -497.795834
# 1                                 -498.695773
# 2                                 -498.767484
# 3                                 -498.350935
# 4                                 -500.786497
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                  8.016656
# 1                                  8.130979
# 2                                  8.096893
# 3                                  8.074946
# 4                                  8.054678
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -501.289139
# 1                                 -499.634209
# 2                                 -500.827423
# 3                                 -499.474407
# 4                                 -500.397500
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                  7.946562
# 1                                  7.958270
# 2                                  8.071056
# 3                                  7.897085
# 4                                  8.107890
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -432.317850
# 1                                 -525.839648
# 2                                 -500.801673
# 3                                 -500.868509
# 4                                 -509.526725
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                  4.872511
# 1                                  4.878850
# 2                                  4.905125
# 3                                  4.931400
# 4                                  4.957674
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.037437
# 1                                 -500.162375
# 2                                 -499.828510
# 3                                 -499.963623
# 4                                 -500.360026
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 26.705889
# 1                                 25.019940
# 2                                 24.994862
# 3                                 24.948919
# 4                                 25.003331
#
#    secondary_cleaner.state.floatbank6_a_level
# 0                                 -499.709414
# 1                                 -499.819438
# 2                                 -500.622559
# 3                                 -498.709987
# 4                                 -500.856333
#
# [5 rows x 53 columns]
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# 2                    42.657501              68.116445             10.507046
# 3                    42.689819              68.347543             10.422762
# 4                    42.774141              66.927016             10.360302
#
#    final.output.tail_pb  final.output.tail_sol  final.output.tail_au  ...  \
# 0              0.895447              16.904297              2.143149  ...
# 1              0.927452              16.634514              2.224930  ...
# 2              0.953716              16.208849              2.257889  ...
# 3              0.883763              16.532835              2.146849  ...
# 4              0.792826              16.525686              2.055292  ...
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 14.016835
# 1                                 13.992281
# 2                                 14.015015
# 3                                 14.036510
# 4                                 14.027298
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -502.488007
# 1                                 -505.503262
# 2                                 -502.520901
# 3                                 -500.857308
# 4                                 -499.838632
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                 12.099931
# 1                                 11.950531
# 2                                 11.912783
# 3                                 11.999550
# 4                                 11.953070
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -504.715942
# 1                                 -501.331529
# 2                                 -501.133383
# 3                                 -501.193686
# 4                                 -501.053894
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                  9.925633
# 1                                 10.039245
# 2                                 10.070913
# 3                                  9.970366
# 4                                  9.925709
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -498.310211
# 1                                 -500.169983
# 2                                 -500.129135
# 3                                 -499.201640
# 4                                 -501.686727
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                  8.079666
# 1                                  7.984757
# 2                                  8.013877
# 3                                  7.977324
# 4                                  7.894242
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.470978
# 1                                 -500.582168
# 2                                 -500.517572
# 3                                 -500.255908
# 4                                 -500.356035
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 14.151341
# 1                                 13.998353
# 2                                 14.028663
# 3                                 14.005551
# 4                                 13.996647
#
#    secondary_cleaner.state.floatbank6_a_level
# 0                                 -605.841980
# 1                                 -599.787184
# 2                                 -601.427363
# 3                                 -599.996129
# 4                                 -601.496691
#
# [5 rows x 87 columns]

# %%
pd.DataFrame(round(train_data.isna().mean()*100,)).style.background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_1c1c1_row0_col0, #T_1c1c1_row1_col0, #T_1c1c1_row2_col0, #T_1c1c1_row4_col0, #T_1c1c1_row5_col0, #T_1c1c1_row6_col0, #T_1c1c1_row8_col0, #T_1c1c1_row9_col0, #T_1c1c1_row10_col0, #T_1c1c1_row11_col0, #T_1c1c1_row12_col0, #T_1c1c1_row14_col0, #T_1c1c1_row17_col0, #T_1c1c1_row18_col0, #T_1c1c1_row19_col0, #T_1c1c1_row20_col0, #T_1c1c1_row21_col0, #T_1c1c1_row22_col0, #T_1c1c1_row23_col0, #T_1c1c1_row24_col0, #T_1c1c1_row25_col0, #T_1c1c1_row26_col0, #T_1c1c1_row27_col0, #T_1c1c1_row28_col0, #T_1c1c1_row29_col0, #T_1c1c1_row30_col0, #T_1c1c1_row31_col0, #T_1c1c1_row32_col0, #T_1c1c1_row33_col0, #T_1c1c1_row34_col0, #T_1c1c1_row36_col0, #T_1c1c1_row39_col0, #T_1c1c1_row40_col0, #T_1c1c1_row41_col0, #T_1c1c1_row42_col0, #T_1c1c1_row44_col0, #T_1c1c1_row45_col0, #T_1c1c1_row46_col0, #T_1c1c1_row47_col0, #T_1c1c1_row48_col0, #T_1c1c1_row49_col0, #T_1c1c1_row50_col0, #T_1c1c1_row51_col0, #T_1c1c1_row52_col0, #T_1c1c1_row53_col0, #T_1c1c1_row54_col0, #T_1c1c1_row55_col0, #T_1c1c1_row56_col0, #T_1c1c1_row57_col0, #T_1c1c1_row58_col0, #T_1c1c1_row59_col0, #T_1c1c1_row60_col0, #T_1c1c1_row62_col0, #T_1c1c1_row63_col0, #T_1c1c1_row64_col0, #T_1c1c1_row65_col0, #T_1c1c1_row66_col0, #T_1c1c1_row68_col0, #T_1c1c1_row70_col0, #T_1c1c1_row71_col0, #T_1c1c1_row72_col0, #T_1c1c1_row73_col0, #T_1c1c1_row74_col0, #T_1c1c1_row75_col0, #T_1c1c1_row76_col0, #T_1c1c1_row77_col0, #T_1c1c1_row78_col0, #T_1c1c1_row79_col0, #T_1c1c1_row80_col0, #T_1c1c1_row81_col0, #T_1c1c1_row82_col0, #T_1c1c1_row83_col0, #T_1c1c1_row84_col0, #T_1c1c1_row85_col0, #T_1c1c1_row86_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1c1c1_row3_col0, #T_1c1c1_row7_col0, #T_1c1c1_row13_col0, #T_1c1c1_row15_col0, #T_1c1c1_row35_col0, #T_1c1c1_row37_col0, #T_1c1c1_row38_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_1c1c1_row16_col0, #T_1c1c1_row69_col0 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_1c1c1_row43_col0, #T_1c1c1_row61_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_1c1c1_row67_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1c1c1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c1c1_level0_row0" class="row_heading level0 row0" >date</th>
#       <td id="T_1c1c1_row0_col0" class="data row0 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row1" class="row_heading level0 row1" >final.output.concentrate_ag</th>
#       <td id="T_1c1c1_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row2" class="row_heading level0 row2" >final.output.concentrate_pb</th>
#       <td id="T_1c1c1_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row3" class="row_heading level0 row3" >final.output.concentrate_sol</th>
#       <td id="T_1c1c1_row3_col0" class="data row3 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row4" class="row_heading level0 row4" >final.output.concentrate_au</th>
#       <td id="T_1c1c1_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row5" class="row_heading level0 row5" >final.output.recovery</th>
#       <td id="T_1c1c1_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row6" class="row_heading level0 row6" >final.output.tail_ag</th>
#       <td id="T_1c1c1_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row7" class="row_heading level0 row7" >final.output.tail_pb</th>
#       <td id="T_1c1c1_row7_col0" class="data row7 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row8" class="row_heading level0 row8" >final.output.tail_sol</th>
#       <td id="T_1c1c1_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row9" class="row_heading level0 row9" >final.output.tail_au</th>
#       <td id="T_1c1c1_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row10" class="row_heading level0 row10" >primary_cleaner.input.sulfate</th>
#       <td id="T_1c1c1_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row11" class="row_heading level0 row11" >primary_cleaner.input.depressant</th>
#       <td id="T_1c1c1_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row12" class="row_heading level0 row12" >primary_cleaner.input.feed_size</th>
#       <td id="T_1c1c1_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row13" class="row_heading level0 row13" >primary_cleaner.input.xanthate</th>
#       <td id="T_1c1c1_row13_col0" class="data row13 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row14" class="row_heading level0 row14" >primary_cleaner.output.concentrate_ag</th>
#       <td id="T_1c1c1_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row15" class="row_heading level0 row15" >primary_cleaner.output.concentrate_pb</th>
#       <td id="T_1c1c1_row15_col0" class="data row15 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row16" class="row_heading level0 row16" >primary_cleaner.output.concentrate_sol</th>
#       <td id="T_1c1c1_row16_col0" class="data row16 col0" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row17" class="row_heading level0 row17" >primary_cleaner.output.concentrate_au</th>
#       <td id="T_1c1c1_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row18" class="row_heading level0 row18" >primary_cleaner.output.tail_ag</th>
#       <td id="T_1c1c1_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row19" class="row_heading level0 row19" >primary_cleaner.output.tail_pb</th>
#       <td id="T_1c1c1_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row20" class="row_heading level0 row20" >primary_cleaner.output.tail_sol</th>
#       <td id="T_1c1c1_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row21" class="row_heading level0 row21" >primary_cleaner.output.tail_au</th>
#       <td id="T_1c1c1_row21_col0" class="data row21 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row22" class="row_heading level0 row22" >primary_cleaner.state.floatbank8_a_air</th>
#       <td id="T_1c1c1_row22_col0" class="data row22 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row23" class="row_heading level0 row23" >primary_cleaner.state.floatbank8_a_level</th>
#       <td id="T_1c1c1_row23_col0" class="data row23 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row24" class="row_heading level0 row24" >primary_cleaner.state.floatbank8_b_air</th>
#       <td id="T_1c1c1_row24_col0" class="data row24 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row25" class="row_heading level0 row25" >primary_cleaner.state.floatbank8_b_level</th>
#       <td id="T_1c1c1_row25_col0" class="data row25 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row26" class="row_heading level0 row26" >primary_cleaner.state.floatbank8_c_air</th>
#       <td id="T_1c1c1_row26_col0" class="data row26 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row27" class="row_heading level0 row27" >primary_cleaner.state.floatbank8_c_level</th>
#       <td id="T_1c1c1_row27_col0" class="data row27 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c1c1_level0_row28" class="row_heading level0 row28" >primary_cleaner.state.floatbank8_d_air</th>
#       <td id="T_1c1c1_row28_col0" class="data row28 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="

# %%
pd.DataFrame(round(test_data.isna().mean()*100,)).style.background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_fced1_row0_col0, #T_fced1_row1_col0, #T_fced1_row2_col0, #T_fced1_row3_col0, #T_fced1_row4_col0, #T_fced1_row5_col0, #T_fced1_row6_col0, #T_fced1_row7_col0, #T_fced1_row8_col0, #T_fced1_row9_col0, #T_fced1_row10_col0, #T_fced1_row11_col0, #T_fced1_row12_col0, #T_fced1_row13_col0, #T_fced1_row14_col0, #T_fced1_row15_col0, #T_fced1_row16_col0, #T_fced1_row17_col0, #T_fced1_row18_col0, #T_fced1_row19_col0, #T_fced1_row20_col0, #T_fced1_row21_col0, #T_fced1_row22_col0, #T_fced1_row23_col0, #T_fced1_row24_col0, #T_fced1_row25_col0, #T_fced1_row26_col0, #T_fced1_row27_col0, #T_fced1_row28_col0, #T_fced1_row29_col0, #T_fced1_row30_col0, #T_fced1_row31_col0, #T_fced1_row32_col0, #T_fced1_row33_col0, #T_fced1_row34_col0, #T_fced1_row35_col0, #T_fced1_row36_col0, #T_fced1_row37_col0, #T_fced1_row38_col0, #T_fced1_row39_col0, #T_fced1_row40_col0, #T_fced1_row41_col0, #T_fced1_row42_col0, #T_fced1_row43_col0, #T_fced1_row44_col0, #T_fced1_row45_col0, #T_fced1_row46_col0, #T_fced1_row47_col0, #T_fced1_row48_col0, #T_fced1_row49_col0, #T_fced1_row50_col0, #T_fced1_row51_col0, #T_fced1_row52_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fced1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fced1_level0_row0" class="row_heading level0 row0" >date</th>
#       <td id="T_fced1_row0_col0" class="data row0 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row1" class="row_heading level0 row1" >primary_cleaner.input.sulfate</th>
#       <td id="T_fced1_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row2" class="row_heading level0 row2" >primary_cleaner.input.depressant</th>
#       <td id="T_fced1_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row3" class="row_heading level0 row3" >primary_cleaner.input.feed_size</th>
#       <td id="T_fced1_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row4" class="row_heading level0 row4" >primary_cleaner.input.xanthate</th>
#       <td id="T_fced1_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row5" class="row_heading level0 row5" >primary_cleaner.state.floatbank8_a_air</th>
#       <td id="T_fced1_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row6" class="row_heading level0 row6" >primary_cleaner.state.floatbank8_a_level</th>
#       <td id="T_fced1_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row7" class="row_heading level0 row7" >primary_cleaner.state.floatbank8_b_air</th>
#       <td id="T_fced1_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row8" class="row_heading level0 row8" >primary_cleaner.state.floatbank8_b_level</th>
#       <td id="T_fced1_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row9" class="row_heading level0 row9" >primary_cleaner.state.floatbank8_c_air</th>
#       <td id="T_fced1_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row10" class="row_heading level0 row10" >primary_cleaner.state.floatbank8_c_level</th>
#       <td id="T_fced1_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row11" class="row_heading level0 row11" >primary_cleaner.state.floatbank8_d_air</th>
#       <td id="T_fced1_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row12" class="row_heading level0 row12" >primary_cleaner.state.floatbank8_d_level</th>
#       <td id="T_fced1_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row13" class="row_heading level0 row13" >rougher.input.feed_ag</th>
#       <td id="T_fced1_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row14" class="row_heading level0 row14" >rougher.input.feed_pb</th>
#       <td id="T_fced1_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row15" class="row_heading level0 row15" >rougher.input.feed_rate</th>
#       <td id="T_fced1_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row16" class="row_heading level0 row16" >rougher.input.feed_size</th>
#       <td id="T_fced1_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row17" class="row_heading level0 row17" >rougher.input.feed_sol</th>
#       <td id="T_fced1_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row18" class="row_heading level0 row18" >rougher.input.feed_au</th>
#       <td id="T_fced1_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row19" class="row_heading level0 row19" >rougher.input.floatbank10_sulfate</th>
#       <td id="T_fced1_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row20" class="row_heading level0 row20" >rougher.input.floatbank10_xanthate</th>
#       <td id="T_fced1_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row21" class="row_heading level0 row21" >rougher.input.floatbank11_sulfate</th>
#       <td id="T_fced1_row21_col0" class="data row21 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row22" class="row_heading level0 row22" >rougher.input.floatbank11_xanthate</th>
#       <td id="T_fced1_row22_col0" class="data row22 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row23" class="row_heading level0 row23" >rougher.state.floatbank10_a_air</th>
#       <td id="T_fced1_row23_col0" class="data row23 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row24" class="row_heading level0 row24" >rougher.state.floatbank10_a_level</th>
#       <td id="T_fced1_row24_col0" class="data row24 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row25" class="row_heading level0 row25" >rougher.state.floatbank10_b_air</th>
#       <td id="T_fced1_row25_col0" class="data row25 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row26" class="row_heading level0 row26" >rougher.state.floatbank10_b_level</th>
#       <td id="T_fced1_row26_col0" class="data row26 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row27" class="row_heading level0 row27" >rougher.state.floatbank10_c_air</th>
#       <td id="T_fced1_row27_col0" class="data row27 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row28" class="row_heading level0 row28" >rougher.state.floatbank10_c_level</th>
#       <td id="T_fced1_row28_col0" class="data row28 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row29" class="row_heading level0 row29" >rougher.state.floatbank10_d_air</th>
#       <td id="T_fced1_row29_col0" class="data row29 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row30" class="row_heading level0 row30" >rougher.state.floatbank10_d_level</th>
#       <td id="T_fced1_row30_col0" class="data row30 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row31" class="row_heading level0 row31" >rougher.state.floatbank10_e_air</th>
#       <td id="T_fced1_row31_col0" class="data row31 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row32" class="row_heading level0 row32" >rougher.state.floatbank10_e_level</th>
#       <td id="T_fced1_row32_col0" class="data row32 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fced1_level0_row33" class="row_heading level0 row33" >rougher.state.floatbank10_f_air</th>

# %%
pd.DataFrame(round(full_data.isna().mean()*100,)).style.background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_45f07_row0_col0, #T_45f07_row1_col0, #T_45f07_row2_col0, #T_45f07_row4_col0, #T_45f07_row5_col0, #T_45f07_row6_col0, #T_45f07_row8_col0, #T_45f07_row9_col0, #T_45f07_row10_col0, #T_45f07_row11_col0, #T_45f07_row12_col0, #T_45f07_row14_col0, #T_45f07_row17_col0, #T_45f07_row18_col0, #T_45f07_row19_col0, #T_45f07_row20_col0, #T_45f07_row21_col0, #T_45f07_row22_col0, #T_45f07_row23_col0, #T_45f07_row24_col0, #T_45f07_row25_col0, #T_45f07_row26_col0, #T_45f07_row27_col0, #T_45f07_row28_col0, #T_45f07_row29_col0, #T_45f07_row30_col0, #T_45f07_row31_col0, #T_45f07_row32_col0, #T_45f07_row33_col0, #T_45f07_row34_col0, #T_45f07_row36_col0, #T_45f07_row39_col0, #T_45f07_row40_col0, #T_45f07_row41_col0, #T_45f07_row42_col0, #T_45f07_row44_col0, #T_45f07_row45_col0, #T_45f07_row46_col0, #T_45f07_row47_col0, #T_45f07_row48_col0, #T_45f07_row49_col0, #T_45f07_row50_col0, #T_45f07_row51_col0, #T_45f07_row52_col0, #T_45f07_row53_col0, #T_45f07_row54_col0, #T_45f07_row55_col0, #T_45f07_row56_col0, #T_45f07_row57_col0, #T_45f07_row58_col0, #T_45f07_row59_col0, #T_45f07_row60_col0, #T_45f07_row62_col0, #T_45f07_row63_col0, #T_45f07_row64_col0, #T_45f07_row65_col0, #T_45f07_row66_col0, #T_45f07_row68_col0, #T_45f07_row70_col0, #T_45f07_row71_col0, #T_45f07_row72_col0, #T_45f07_row73_col0, #T_45f07_row74_col0, #T_45f07_row75_col0, #T_45f07_row76_col0, #T_45f07_row77_col0, #T_45f07_row78_col0, #T_45f07_row79_col0, #T_45f07_row80_col0, #T_45f07_row81_col0, #T_45f07_row82_col0, #T_45f07_row83_col0, #T_45f07_row84_col0, #T_45f07_row85_col0, #T_45f07_row86_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_45f07_row3_col0, #T_45f07_row7_col0, #T_45f07_row13_col0, #T_45f07_row15_col0, #T_45f07_row35_col0, #T_45f07_row37_col0, #T_45f07_row38_col0, #T_45f07_row69_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_45f07_row16_col0, #T_45f07_row43_col0, #T_45f07_row61_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_45f07_row67_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_45f07_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45f07_level0_row0" class="row_heading level0 row0" >date</th>
#       <td id="T_45f07_row0_col0" class="data row0 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row1" class="row_heading level0 row1" >final.output.concentrate_ag</th>
#       <td id="T_45f07_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row2" class="row_heading level0 row2" >final.output.concentrate_pb</th>
#       <td id="T_45f07_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row3" class="row_heading level0 row3" >final.output.concentrate_sol</th>
#       <td id="T_45f07_row3_col0" class="data row3 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row4" class="row_heading level0 row4" >final.output.concentrate_au</th>
#       <td id="T_45f07_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row5" class="row_heading level0 row5" >final.output.recovery</th>
#       <td id="T_45f07_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row6" class="row_heading level0 row6" >final.output.tail_ag</th>
#       <td id="T_45f07_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row7" class="row_heading level0 row7" >final.output.tail_pb</th>
#       <td id="T_45f07_row7_col0" class="data row7 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row8" class="row_heading level0 row8" >final.output.tail_sol</th>
#       <td id="T_45f07_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row9" class="row_heading level0 row9" >final.output.tail_au</th>
#       <td id="T_45f07_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row10" class="row_heading level0 row10" >primary_cleaner.input.sulfate</th>
#       <td id="T_45f07_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row11" class="row_heading level0 row11" >primary_cleaner.input.depressant</th>
#       <td id="T_45f07_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row12" class="row_heading level0 row12" >primary_cleaner.input.feed_size</th>
#       <td id="T_45f07_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row13" class="row_heading level0 row13" >primary_cleaner.input.xanthate</th>
#       <td id="T_45f07_row13_col0" class="data row13 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row14" class="row_heading level0 row14" >primary_cleaner.output.concentrate_ag</th>
#       <td id="T_45f07_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row15" class="row_heading level0 row15" >primary_cleaner.output.concentrate_pb</th>
#       <td id="T_45f07_row15_col0" class="data row15 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row16" class="row_heading level0 row16" >primary_cleaner.output.concentrate_sol</th>
#       <td id="T_45f07_row16_col0" class="data row16 col0" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row17" class="row_heading level0 row17" >primary_cleaner.output.concentrate_au</th>
#       <td id="T_45f07_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row18" class="row_heading level0 row18" >primary_cleaner.output.tail_ag</th>
#       <td id="T_45f07_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row19" class="row_heading level0 row19" >primary_cleaner.output.tail_pb</th>
#       <td id="T_45f07_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row20" class="row_heading level0 row20" >primary_cleaner.output.tail_sol</th>
#       <td id="T_45f07_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row21" class="row_heading level0 row21" >primary_cleaner.output.tail_au</th>
#       <td id="T_45f07_row21_col0" class="data row21 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row22" class="row_heading level0 row22" >primary_cleaner.state.floatbank8_a_air</th>
#       <td id="T_45f07_row22_col0" class="data row22 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row23" class="row_heading level0 row23" >primary_cleaner.state.floatbank8_a_level</th>
#       <td id="T_45f07_row23_col0" class="data row23 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row24" class="row_heading level0 row24" >primary_cleaner.state.floatbank8_b_air</th>
#       <td id="T_45f07_row24_col0" class="data row24 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row25" class="row_heading level0 row25" >primary_cleaner.state.floatbank8_b_level</th>
#       <td id="T_45f07_row25_col0" class="data row25 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row26" class="row_heading level0 row26" >primary_cleaner.state.floatbank8_c_air</th>
#       <td id="T_45f07_row26_col0" class="data row26 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row27" class="row_heading level0 row27" >primary_cleaner.state.floatbank8_c_level</th>
#       <td id="T_45f07_row27_col0" class="data row27 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row28" class="row_heading level0 row28" >primary_cleaner.state.floatbank8_d_air</th>
#       <td id="T_45f07_row28_col0" class="data row28 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45f07_level0_row29" class="row_heading level0 ro

# %%
print('Shape of an array: {}'.format(train_data['date'].shape))
# Out:
# Shape of an array: (14149,)

# %%
print('Shape of an array: {}'.format(test_data['date'].shape))
# Out:
# Shape of an array: (5290,)

# %%
print('Shape of an array: {}'.format(full_data['date'].shape))
# Out:
# Shape of an array: (19439,)

# %%
print(train_data.isnull().sum(axis=0))
# Out:
# date                                            0
# final.output.concentrate_ag                     1
# final.output.concentrate_pb                     1
# final.output.concentrate_sol                  211
# final.output.concentrate_au                     0
#                                              ...
# secondary_cleaner.state.floatbank5_a_level      1
# secondary_cleaner.state.floatbank5_b_air        1
# secondary_cleaner.state.floatbank5_b_level      1
# secondary_cleaner.state.floatbank6_a_air        2
# secondary_cleaner.state.floatbank6_a_level      1
# Length: 87, dtype: int64

# %%
print(test_data.isnull().sum(axis=0))
# Out:
# date                                           0
# primary_cleaner.input.sulfate                  4
# primary_cleaner.input.depressant               5
# primary_cleaner.input.feed_size                0
# primary_cleaner.input.xanthate                 4
# primary_cleaner.state.floatbank8_a_air         0
# primary_cleaner.state.floatbank8_a_level       0
# primary_cleaner.state.floatbank8_b_air         0
# primary_cleaner.state.floatbank8_b_level       0
# primary_cleaner.state.floatbank8_c_air         0
# primary_cleaner.state.floatbank8_c_level       0
# primary_cleaner.state.floatbank8_d_air         0
# primary_cleaner.state.floatbank8_d_level       0
# rougher.input.feed_ag                          0
# rougher.input.feed_pb                          0
# rougher.input.feed_rate                        3
# rougher.input.feed_size                        1
# rougher.input.feed_sol                        21
# rougher.input.feed_au                          0
# rougher.input.floatbank10_sulfate              5
# rougher.input.floatbank10_xanthate             0
# rougher.input.floatbank11_sulfate              8
# rougher.input.floatbank11_xanthate            25
# rougher.state.floatbank10_a_air                0
# rougher.state.floatbank10_a_level              0
# rougher.state.floatbank10_b_air                0
# rougher.state.floatbank10_b_level              0
# rougher.state.floatbank10_c_air                0
# rougher.state.floatbank10_c_level              0
# rougher.state.floatbank10_d_air                0
# rougher.state.floatbank10_d_level              0
# rougher.state.floatbank10_e_air                0
# rougher.state.floatbank10_e_level              0
# rougher.state.floatbank10_f_air                0
# rougher.state.floatbank10_f_level              0
# secondary_cleaner.state.floatbank2_a_air       3
# secondary_cleaner.state.floatbank2_a_level     0
# secondary_cleaner.state.floatbank2_b_air       2
# secondary_cleaner.state.floatbank2_b_level     0
# secondary_cleaner.state.floatbank3_a_air       9
# secondary_cleaner.state.floatbank3_a_level     0
# secondary_cleaner.state.floatbank3_b_air       0
# secondary_cleaner.state.floatbank3_b_level     0
# secondary_cleaner.state.floatbank4_a_air       0
# secondary_cleaner.state.floatbank4_a_level     0
# secondary_cleaner.state.floatbank4_b_air       0
# secondary_cleaner.state.floatbank4_b_level     0
# secondary_cleaner.state.floatbank5_a_air       0
# secondary_cleaner.state.floatbank5_a_level     0
# secondary_cleaner.state.floatbank5_b_air       0
# secondary_cleaner.state.floatbank5_b_level     0
# secondary_cleaner.state.floatbank6_a_air       0
# secondary_cleaner.state.floatbank6_a_level     0
# dtype: int64

# %%
print(full_data.isnull().sum(axis=0))
# Out:
# date                                            0
# final.output.concentrate_ag                     1
# final.output.concentrate_pb                     1
# final.output.concentrate_sol                  211
# final.output.concentrate_au                     0
#                                              ...
# secondary_cleaner.state.floatbank5_a_level      1
# secondary_cleaner.state.floatbank5_b_air        1
# secondary_cleaner.state.floatbank5_b_level      1
# secondary_cleaner.state.floatbank6_a_air        2
# secondary_cleaner.state.floatbank6_a_level      1
# Length: 87, dtype: int64

# %% [markdown]
# ### Missing valies: Choosing a replacement strategy

# %% [markdown]
# - train_data

# %%
# interpolates secondary_cleaner.output.tail_sol (11% of missings)
train_data['secondary_cleaner.output.tail_sol'].interpolate(method='linear', inplace=True)

# dropping NAs which are less then 10%
train_data = train_data.dropna(subset=['final.output.concentrate_sol'])
train_data = train_data.dropna(subset=['final.output.tail_pb'])
train_data = train_data.dropna(subset=['primary_cleaner.input.xanthate'])
train_data = train_data.dropna(subset=['primary_cleaner.output.concentrate_pb'])
train_data = train_data.dropna(subset=['primary_cleaner.output.concentrate_sol'])
train_data = train_data.dropna(subset=['rougher.input.feed_pb'])
train_data = train_data.dropna(subset=['rougher.input.feed_size'])
train_data = train_data.dropna(subset=['rougher.input.feed_sol'])
train_data = train_data.dropna(subset=['rougher.input.floatbank11_xanthate'])
train_data = train_data.dropna(subset=['rougher.state.floatbank10_e_air'])
train_data = train_data.dropna(subset=['secondary_cleaner.state.floatbank2_a_air'])

# final check
pd.DataFrame(round(train_data.isna().mean()*100,)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_ca403_row0_col0,#T_ca403_row1_col0,#T_ca403_row2_col0,#T_ca403_row3_col0,#T_ca403_row4_col0,#T_ca403_row5_col0,#T_ca403_row6_col0,#T_ca403_row7_col0,#T_ca403_row8_col0,#T_ca403_row9_col0,#T_ca403_row10_col0,#T_ca403_row11_col0,#T_ca403_row12_col0,#T_ca403_row13_col0,#T_ca403_row14_col0,#T_ca403_row15_col0,#T_ca403_row16_col0,#T_ca403_row17_col0,#T_ca403_row18_col0,#T_ca403_row19_col0,#T_ca403_row20_col0,#T_ca403_row21_col0,#T_ca403_row22_col0,#T_ca403_row23_col0,#T_ca403_row24_col0,#T_ca403_row25_col0,#T_ca403_row26_col0,#T_ca403_row27_col0,#T_ca403_row28_col0,#T_ca403_row29_col0,#T_ca403_row30_col0,#T_ca403_row31_col0,#T_ca403_row32_col0,#T_ca403_row33_col0,#T_ca403_row34_col0,#T_ca403_row35_col0,#T_ca403_row36_col0,#T_ca403_row37_col0,#T_ca403_row38_col0,#T_ca403_row39_col0,#T_ca403_row40_col0,#T_ca403_row41_col0,#T_ca403_row42_col0,#T_ca403_row43_col0,#T_ca403_row44_col0,#T_ca403_row45_col0,#T_ca403_row46_col0,#T_ca403_row47_col0,#T_ca403_row48_col0,#T_ca403_row49_col0,#T_ca403_row50_col0,#T_ca403_row51_col0,#T_ca403_row52_col0,#T_ca403_row53_col0,#T_ca403_row54_col0,#T_ca403_row55_col0,#T_ca403_row56_col0,#T_ca403_row57_col0,#T_ca403_row58_col0,#T_ca403_row59_col0,#T_ca403_row60_col0,#T_ca403_row61_col0,#T_ca403_row62_col0,#T_ca403_row63_col0,#T_ca403_row64_col0,#T_ca403_row65_col0,#T_ca403_row66_col0,#T_ca403_row67_col0,#T_ca403_row68_col0,#T_ca403_row69_col0,#T_ca403_row70_col0,#T_ca403_row71_col0,#T_ca403_row72_col0,#T_ca403_row73_col0,#T_ca403_row74_col0,#T_ca403_row75_col0,#T_ca403_row76_col0,#T_ca403_row77_col0,#T_ca403_row78_col0,#T_ca403_row79_col0,#T_ca403_row80_col0,#T_ca403_row81_col0,#T_ca403_row82_col0,#T_ca403_row83_col0,#T_ca403_row84_col0,#T_ca403_row85_col0,#T_ca403_row86_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_ca403_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ca403_level0_row0" class="row_heading level0 row0" >date</th>
#                         <td id="T_ca403_row0_col0" class="data row0 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row1" class="row_heading level0 row1" >final.output.concentrate_ag</th>
#                         <td id="T_ca403_row1_col0" class="data row1 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row2" class="row_heading level0 row2" >final.output.concentrate_pb</th>
#                         <td id="T_ca403_row2_col0" class="data row2 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row3" class="row_heading level0 row3" >final.output.concentrate_sol</th>
#                         <td id="T_ca403_row3_col0" class="data row3 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row4" class="row_heading level0 row4" >final.output.concentrate_au</th>
#                         <td id="T_ca403_row4_col0" class="data row4 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row5" class="row_heading level0 row5" >final.output.recovery</th>
#                         <td id="T_ca403_row5_col0" class="data row5 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row6" class="row_heading level0 row6" >final.output.tail_ag</th>
#                         <td id="T_ca403_row6_col0" class="data row6 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row7" class="row_heading level0 row7" >final.output.tail_pb</th>
#                         <td id="T_ca403_row7_col0" class="data row7 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row8" class="row_heading level0 row8" >final.output.tail_sol</th>
#                         <td id="T_ca403_row8_col0" class="data row8 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row9" class="row_heading level0 row9" >final.output.tail_au</th>
#                         <td id="T_ca403_row9_col0" class="data row9 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row10" class="row_heading level0 row10" >primary_cleaner.input.sulfate</th>
#                         <td id="T_ca403_row10_col0" class="data row10 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row11" class="row_heading level0 row11" >primary_cleaner.input.depressant</th>
#                         <td id="T_ca403_row11_col0" class="data row11 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row12" class="row_heading level0 row12" >primary_cleaner.input.feed_size</th>
#                         <td id="T_ca403_row12_col0" class="data row12 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row13" class="row_heading level0 row13" >primary_cleaner.input.xanthate</th>
#                         <td id="T_ca403_row13_col0" class="data row13 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row14" class="row_heading level0 row14" >primary_cleaner.output.concentrate_ag</th>
#                         <td id="T_ca403_row14_col0" class="data row14 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row15" class="row_heading level0 row15" >primary_cleaner.output.concentrate_pb</th>
#                         <td id="T_ca403_row15_col0" class="data row15 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row16" class="row_heading level0 row16" >primary_cleaner.output.concentrate_sol</th>
#                         <td id="T_ca403_row16_col0" class="data row16 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row17" class="row_heading level0 row17" >primary_cleaner.output.concentrate_au</th>
#                         <td id="T_ca403_row17_col0" class="data row17 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row18" class="row_heading level0 row18" >primary_cleaner.output.tail_ag</th>
#                         <td id="T_ca403_row18_col0" class="data row18 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row19" class="row_heading level0 row19" >primary_cleaner.output.tail_pb</th>
#                         <td id="T_ca403_row19_col0" class="data row19 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row20" class="row_heading level0 row20" >primary_cleaner.output.tail_sol</th>
#                         <td id="T_ca403_row20_col0" class="data row20 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row21" class="row_heading level0 row21" >primary_cleaner.output.tail_au</th>
#                         <td id="T_ca403_row21_col0" class="data row21 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row22" class="row_heading level0 row22" >primary_cleaner.state.floatbank8_a_air</th>
#                         <td id="T_ca403_row22_col0" class="data row22 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row23" class="row_heading level0 row23" >primary_cleaner.state.floatbank8_a_level</th>
#                         <td id="T_ca403_row23_col0" class="data row23 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ca403_level0_row24" class

# %% [markdown]
# - test_data

# %%
# dropping NAs which are less then 10%
test_data = test_data.dropna(subset=['primary_cleaner.input.xanthate'])
test_data = test_data.dropna(subset=['rougher.input.feed_pb'])
test_data = test_data.dropna(subset=['rougher.input.feed_size'])
test_data = test_data.dropna(subset=['rougher.input.feed_sol'])
test_data = test_data.dropna(subset=['rougher.input.floatbank11_xanthate'])
test_data = test_data.dropna(subset=['rougher.state.floatbank10_e_air'])
test_data = test_data.dropna(subset=['secondary_cleaner.state.floatbank2_a_air'])

# final check
pd.DataFrame(round(test_data.isna().mean()*100,)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_cbb55_row0_col0,#T_cbb55_row1_col0,#T_cbb55_row2_col0,#T_cbb55_row3_col0,#T_cbb55_row4_col0,#T_cbb55_row5_col0,#T_cbb55_row6_col0,#T_cbb55_row7_col0,#T_cbb55_row8_col0,#T_cbb55_row9_col0,#T_cbb55_row10_col0,#T_cbb55_row11_col0,#T_cbb55_row12_col0,#T_cbb55_row13_col0,#T_cbb55_row14_col0,#T_cbb55_row15_col0,#T_cbb55_row16_col0,#T_cbb55_row17_col0,#T_cbb55_row18_col0,#T_cbb55_row19_col0,#T_cbb55_row20_col0,#T_cbb55_row21_col0,#T_cbb55_row22_col0,#T_cbb55_row23_col0,#T_cbb55_row24_col0,#T_cbb55_row25_col0,#T_cbb55_row26_col0,#T_cbb55_row27_col0,#T_cbb55_row28_col0,#T_cbb55_row29_col0,#T_cbb55_row30_col0,#T_cbb55_row31_col0,#T_cbb55_row32_col0,#T_cbb55_row33_col0,#T_cbb55_row34_col0,#T_cbb55_row35_col0,#T_cbb55_row36_col0,#T_cbb55_row37_col0,#T_cbb55_row38_col0,#T_cbb55_row39_col0,#T_cbb55_row40_col0,#T_cbb55_row41_col0,#T_cbb55_row42_col0,#T_cbb55_row43_col0,#T_cbb55_row44_col0,#T_cbb55_row45_col0,#T_cbb55_row46_col0,#T_cbb55_row47_col0,#T_cbb55_row48_col0,#T_cbb55_row49_col0,#T_cbb55_row50_col0,#T_cbb55_row51_col0,#T_cbb55_row52_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_cbb55_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cbb55_level0_row0" class="row_heading level0 row0" >date</th>
#                         <td id="T_cbb55_row0_col0" class="data row0 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row1" class="row_heading level0 row1" >primary_cleaner.input.sulfate</th>
#                         <td id="T_cbb55_row1_col0" class="data row1 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row2" class="row_heading level0 row2" >primary_cleaner.input.depressant</th>
#                         <td id="T_cbb55_row2_col0" class="data row2 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row3" class="row_heading level0 row3" >primary_cleaner.input.feed_size</th>
#                         <td id="T_cbb55_row3_col0" class="data row3 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row4" class="row_heading level0 row4" >primary_cleaner.input.xanthate</th>
#                         <td id="T_cbb55_row4_col0" class="data row4 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row5" class="row_heading level0 row5" >primary_cleaner.state.floatbank8_a_air</th>
#                         <td id="T_cbb55_row5_col0" class="data row5 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row6" class="row_heading level0 row6" >primary_cleaner.state.floatbank8_a_level</th>
#                         <td id="T_cbb55_row6_col0" class="data row6 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row7" class="row_heading level0 row7" >primary_cleaner.state.floatbank8_b_air</th>
#                         <td id="T_cbb55_row7_col0" class="data row7 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row8" class="row_heading level0 row8" >primary_cleaner.state.floatbank8_b_level</th>
#                         <td id="T_cbb55_row8_col0" class="data row8 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row9" class="row_heading level0 row9" >primary_cleaner.state.floatbank8_c_air</th>
#                         <td id="T_cbb55_row9_col0" class="data row9 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row10" class="row_heading level0 row10" >primary_cleaner.state.floatbank8_c_level</th>
#                         <td id="T_cbb55_row10_col0" class="data row10 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row11" class="row_heading level0 row11" >primary_cleaner.state.floatbank8_d_air</th>
#                         <td id="T_cbb55_row11_col0" class="data row11 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row12" class="row_heading level0 row12" >primary_cleaner.state.floatbank8_d_level</th>
#                         <td id="T_cbb55_row12_col0" class="data row12 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row13" class="row_heading level0 row13" >rougher.input.feed_ag</th>
#                         <td id="T_cbb55_row13_col0" class="data row13 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row14" class="row_heading level0 row14" >rougher.input.feed_pb</th>
#                         <td id="T_cbb55_row14_col0" class="data row14 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row15" class="row_heading level0 row15" >rougher.input.feed_rate</th>
#                         <td id="T_cbb55_row15_col0" class="data row15 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row16" class="row_heading level0 row16" >rougher.input.feed_size</th>
#                         <td id="T_cbb55_row16_col0" class="data row16 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row17" class="row_heading level0 row17" >rougher.input.feed_sol</th>
#                         <td id="T_cbb55_row17_col0" class="data row17 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row18" class="row_heading level0 row18" >rougher.input.feed_au</th>
#                         <td id="T_cbb55_row18_col0" class="data row18 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row19" class="row_heading level0 row19" >rougher.input.floatbank10_sulfate</th>
#                         <td id="T_cbb55_row19_col0" class="data row19 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row20" class="row_heading level0 row20" >rougher.input.floatbank10_xanthate</th>
#                         <td id="T_cbb55_row20_col0" class="data row20 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row21" class="row_heading level0 row21" >rougher.input.floatbank11_sulfate</th>
#                         <td id="T_cbb55_row21_col0" class="data row21 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row22" class="row_heading level0 row22" >rougher.input.floatbank11_xanthate</th>
#                         <td id="T_cbb55_row22_col0" class="data row22 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row23" class="row_heading level0 row23" >rougher.state.floatbank10_a_air</th>
#                         <td id="T_cbb55_row23_col0" class="data row23 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row24" class="row_heading level0 row24" >rougher.state.floatbank10_a_level</th>
#                         <td id="T_cbb55_row24_col0" class="data row24 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row25" class="row_heading level0 row25" >rougher.state.floatbank10_b_air</th>
#                         <td id="T_cbb55_row25_col0" class="data row25 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cbb55_level0_row26" class="row_heading level0 row26" >rougher.state.floatbank10_b_level</th>
#                         <td id="T_cbb55_row26_col0" class="

# %% [markdown]
# - full_data

# %%
# interpolates secondary_cleaner.output.tail_sol (11% of missings)
full_data['secondary_cleaner.output.tail_sol'].interpolate(method='linear', inplace=True)

# dropping NAs which are less then 10%
full_data = full_data.dropna(subset=['final.output.concentrate_sol'])
full_data = full_data.dropna(subset=['final.output.tail_pb'])
full_data = full_data.dropna(subset=['primary_cleaner.input.xanthate'])
full_data = full_data.dropna(subset=['primary_cleaner.output.concentrate_pb'])
full_data = full_data.dropna(subset=['primary_cleaner.output.concentrate_sol'])
full_data = full_data.dropna(subset=['rougher.input.feed_pb'])
full_data = full_data.dropna(subset=['rougher.input.feed_size'])
full_data = full_data.dropna(subset=['rougher.input.feed_sol'])
full_data = full_data.dropna(subset=['rougher.input.floatbank11_xanthate'])
full_data = full_data.dropna(subset=['rougher.state.floatbank10_e_air'])
full_data = full_data.dropna(subset=['secondary_cleaner.state.floatbank2_a_air'])

# final check
pd.DataFrame(round(full_data.isna().mean()*100,)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_148d8_row0_col0,#T_148d8_row1_col0,#T_148d8_row2_col0,#T_148d8_row3_col0,#T_148d8_row4_col0,#T_148d8_row5_col0,#T_148d8_row6_col0,#T_148d8_row7_col0,#T_148d8_row8_col0,#T_148d8_row9_col0,#T_148d8_row10_col0,#T_148d8_row11_col0,#T_148d8_row12_col0,#T_148d8_row13_col0,#T_148d8_row14_col0,#T_148d8_row15_col0,#T_148d8_row16_col0,#T_148d8_row17_col0,#T_148d8_row18_col0,#T_148d8_row19_col0,#T_148d8_row20_col0,#T_148d8_row21_col0,#T_148d8_row22_col0,#T_148d8_row23_col0,#T_148d8_row24_col0,#T_148d8_row25_col0,#T_148d8_row26_col0,#T_148d8_row27_col0,#T_148d8_row28_col0,#T_148d8_row29_col0,#T_148d8_row30_col0,#T_148d8_row31_col0,#T_148d8_row32_col0,#T_148d8_row33_col0,#T_148d8_row34_col0,#T_148d8_row35_col0,#T_148d8_row36_col0,#T_148d8_row37_col0,#T_148d8_row38_col0,#T_148d8_row39_col0,#T_148d8_row40_col0,#T_148d8_row41_col0,#T_148d8_row42_col0,#T_148d8_row43_col0,#T_148d8_row44_col0,#T_148d8_row45_col0,#T_148d8_row46_col0,#T_148d8_row47_col0,#T_148d8_row48_col0,#T_148d8_row49_col0,#T_148d8_row50_col0,#T_148d8_row51_col0,#T_148d8_row52_col0,#T_148d8_row53_col0,#T_148d8_row54_col0,#T_148d8_row55_col0,#T_148d8_row56_col0,#T_148d8_row57_col0,#T_148d8_row58_col0,#T_148d8_row59_col0,#T_148d8_row60_col0,#T_148d8_row61_col0,#T_148d8_row62_col0,#T_148d8_row63_col0,#T_148d8_row64_col0,#T_148d8_row65_col0,#T_148d8_row66_col0,#T_148d8_row67_col0,#T_148d8_row68_col0,#T_148d8_row69_col0,#T_148d8_row70_col0,#T_148d8_row71_col0,#T_148d8_row72_col0,#T_148d8_row73_col0,#T_148d8_row74_col0,#T_148d8_row75_col0,#T_148d8_row76_col0,#T_148d8_row77_col0,#T_148d8_row78_col0,#T_148d8_row79_col0,#T_148d8_row80_col0,#T_148d8_row81_col0,#T_148d8_row82_col0,#T_148d8_row83_col0,#T_148d8_row84_col0,#T_148d8_row85_col0,#T_148d8_row86_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_148d8_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_148d8_level0_row0" class="row_heading level0 row0" >date</th>
#                         <td id="T_148d8_row0_col0" class="data row0 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row1" class="row_heading level0 row1" >final.output.concentrate_ag</th>
#                         <td id="T_148d8_row1_col0" class="data row1 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row2" class="row_heading level0 row2" >final.output.concentrate_pb</th>
#                         <td id="T_148d8_row2_col0" class="data row2 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row3" class="row_heading level0 row3" >final.output.concentrate_sol</th>
#                         <td id="T_148d8_row3_col0" class="data row3 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row4" class="row_heading level0 row4" >final.output.concentrate_au</th>
#                         <td id="T_148d8_row4_col0" class="data row4 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row5" class="row_heading level0 row5" >final.output.recovery</th>
#                         <td id="T_148d8_row5_col0" class="data row5 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row6" class="row_heading level0 row6" >final.output.tail_ag</th>
#                         <td id="T_148d8_row6_col0" class="data row6 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row7" class="row_heading level0 row7" >final.output.tail_pb</th>
#                         <td id="T_148d8_row7_col0" class="data row7 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row8" class="row_heading level0 row8" >final.output.tail_sol</th>
#                         <td id="T_148d8_row8_col0" class="data row8 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row9" class="row_heading level0 row9" >final.output.tail_au</th>
#                         <td id="T_148d8_row9_col0" class="data row9 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row10" class="row_heading level0 row10" >primary_cleaner.input.sulfate</th>
#                         <td id="T_148d8_row10_col0" class="data row10 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row11" class="row_heading level0 row11" >primary_cleaner.input.depressant</th>
#                         <td id="T_148d8_row11_col0" class="data row11 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row12" class="row_heading level0 row12" >primary_cleaner.input.feed_size</th>
#                         <td id="T_148d8_row12_col0" class="data row12 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row13" class="row_heading level0 row13" >primary_cleaner.input.xanthate</th>
#                         <td id="T_148d8_row13_col0" class="data row13 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row14" class="row_heading level0 row14" >primary_cleaner.output.concentrate_ag</th>
#                         <td id="T_148d8_row14_col0" class="data row14 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row15" class="row_heading level0 row15" >primary_cleaner.output.concentrate_pb</th>
#                         <td id="T_148d8_row15_col0" class="data row15 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row16" class="row_heading level0 row16" >primary_cleaner.output.concentrate_sol</th>
#                         <td id="T_148d8_row16_col0" class="data row16 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row17" class="row_heading level0 row17" >primary_cleaner.output.concentrate_au</th>
#                         <td id="T_148d8_row17_col0" class="data row17 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row18" class="row_heading level0 row18" >primary_cleaner.output.tail_ag</th>
#                         <td id="T_148d8_row18_col0" class="data row18 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row19" class="row_heading level0 row19" >primary_cleaner.output.tail_pb</th>
#                         <td id="T_148d8_row19_col0" class="data row19 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row20" class="row_heading level0 row20" >primary_cleaner.output.tail_sol</th>
#                         <td id="T_148d8_row20_col0" class="data row20 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row21" class="row_heading level0 row21" >primary_cleaner.output.tail_au</th>
#                         <td id="T_148d8_row21_col0" class="data row21 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row22" class="row_heading level0 row22" >primary_cleaner.state.floatbank8_a_air</th>
#                         <td id="T_148d8_row22_col0" class="data row22 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row23" class="row_heading level0 row23" >primary_cleaner.state.floatbank8_a_level</th>
#                         <td id="T_148d8_row23_col0" class="data row23 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_148d8_level0_row24" class

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> To improve<a class="tocSkip"> </h2>
#
# Все наблюдения представляют собой последовательные измерения, заполнинить пропуски можно и  методами `pandas`: `ffill`/ `bfill`/ интерполяцией , это вполне уместно. Статья, которая рассматривает разные способы обработки пропусков, выделяет их плюсы и минусы: https://loginom.ru/blog/missing

# %% [markdown]
# ### Поиск дубликатов в данных

# %%
train_data.duplicated().sum()
# Out:
# 0

# %%
test_data.duplicated().sum()
# Out:
# 0

# %%
full_data.duplicated().sum()
# Out:
# 0

# %%
# grr = pd.plotting.scatter_matrix(full_data, c=train_data, figsize=(15, 13),
#                            hist_kwds={'bins': 20}, s=60, alpha=.8, cmap=mglearn.cm3)
# plt.show()

# %% [markdown]
# ### Формирование трех новых датасетов на основе очищенных

# %%
pip install datacompy
# Out:
# Collecting datacompy
#   Downloading datacompy-0.8.1-py3-none-any.whl (27 kB)
# Collecting ordered-set<=4.1.0,>=4.0.2
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: pandas<=1.4.2,>=0.25.0 in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from datacompy) (1.3.4)
# Requirement already satisfied: numpy<=1.22.3,>=1.11.3 in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from datacompy) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from pandas<=1.4.2,>=0.25.0->datacompy) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from pandas<=1.4.2,>=0.25.0->datacompy) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/yuliabezginova/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas<=1.4.2,>=0.25.0->datacompy) (1.16.0)
# Installing collected packages: ordered-set, datacompy
# Successfully installed datacompy-0.8.1 ordered-set-4.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import datacompy

# %%
compare = datacompy.Compare(
train_data,
test_data,
join_columns='date',  #You can also specify a list of columns eg ['policyID','statecode']
abs_tol=0, #Optional, defaults to 0
rel_tol=0, #Optional, defaults to 0
df1_name='Original', #Optional, defaults to 'df1'
df2_name='New' #Optional, defaults to 'df2'
)

print(compare.report())
# Out:
# DataComPy Comparison
# --------------------
#
# DataFrame Summary
# -----------------
#
#   DataFrame  Columns   Rows
# 0  Original       87  14149
# 1       New       53   5290
#
# Column Summary
# --------------
#
# Number of columns in common: 53
# Number of columns in Original but not in New: 34
# Number of columns in New but not in Original: 0
#
# Row Summary
# -----------
#
# Matched on: date
# Any duplicates on match values: No
# Absolute Tolerance: 0
# Relative Tolerance: 0
# Number of rows in common: 0
# Number of rows in Original but not in New: 14,149
# Number of rows in New but not in Original: 5,290
#
# Number of rows with some compared columns unequal: 0
# Number of rows with all compared columns equal: 0
#
# Column Comparison
# -----------------
#
# Number of columns compared with some values unequal: 0
# Number of columns compared with all values equal: 53
# Total number of values which compare unequal: 0
#
# Sample Rows Only in Original (First 10 Columns)
# -----------------------------------------------
#
#                       date  final.output.concentrate_ag  final.output.concentrate_pb  final.output.concentrate_sol  final.output.concentrate_au  final.output.recovery  final.output.tail_ag  final.output.tail_pb  final.output.tail_sol  final.output.tail_au
# 8779   2017-07-19 05:59:59                     5.359815                    12.648703                      9.970937                    41.202910              57.303418              8.213345              3.202882               9.938951              3.598092
# 6444   2017-03-28 16:59:59                     4.750955                    10.575239                      9.765607                    46.974893              58.944184              9.811264              3.583165              10.560404              4.106146
# 11782  2018-04-23 03:59:59                     5.014995                    10.090377                      9.103401                    46.336867              76.412599             11.212008              1.524528               8.869654              2.256266
# 13772  2018-07-30 19:59:59                     3.724393                     8.052862                     11.442037                    46.149195              74.447415             13.040599              2.323210              11.789208              2.828801
# 11411  2018-04-06 22:59:59                     4.270654                    10.671541                      8.902847                    46.631791              68.549245              9.620789              1.880832               8.113834              2.335154
# 6490   2017-03-30 14:59:59                     5.095054                    10.518416                     10.517111                    46.317384              78.864689              5.676929              1.943791               7.079086              2.093151
# 324    2016-01-30 07:00:00                     6.276190                    10.980274                      9.492510                    40.620385              70.327115             11.451636              2.271009              19.590170              3.157684
# 3001   2016-06-14 14:59:59                     5.662913                    10.961870                      8.534096                    42.687971              73.031442              7.816039              1.438635              10.484104              2.388796
# 6839   2017-04-14 12:59:59                     4.920841                     8.713882                      8.673190                    36.938599              36.316872              9.969826              2.663830              11.598924              2.698093
# 13728  2018-07-28 20:59:59                     3.274707                     7.809606                      9.719232                    48.059761              68.600745             12.191297              2.825149              10.782964              3.335703
#
# Sample Rows Only in New (First 10 Columns)
# ------------------------------------------
#
#                       date  primary_cleaner.input.sulfate  primary_cleaner.input.depressant  primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  primary_cleaner.state.floatbank8_a_level  primary_cleaner.state.floatbank8_b_air  primary_cleaner.state.floatbank8_b_level  primary_cleaner.state.floatbank8_c_air
# 17395  2017-10-01 16:59:59                     185.884627                          6.549498                         6.680000                        2.212374                             1570.341853                               -500.133269                             1601.449049                               -498.191509                             1602.337382
# 14887  2016-10-11 18:59:59                     178.781625                          8.030959                         7.550000                        1.081950                             1497.027760                               -500.456466                             1501.260615                               -500.049496                             1498.116932
# 15310  2016-10-29 12:59:59                     150.385295                         10.000753                         7.260000                        0.778911                             1640.460570                               -499.952707                             1698.642915                               -500.241084                             1699.759038
# 15830  2016-11-21 03:59:59                     195.160392                          6.017386                         6.880000                        1.186975                             1627.864222                               -499.891382                             1656.472895                               -499.617543                             1653.521967
# 18357  2017-11-13 23:59:59                     185.237711                          6.994064                         6.810000                        2.517719                             1599.910414                               -500.274191                             1601.825108                               -503.654721                             1598.024232
# 14690  2016-10-02 21:59:59                     122.323757                          4.027468                         7.260000                        0.801332                             1617.834591                               -500.485781                             1612.220930                               -499.276339                             1608.708204
# 16988  2017-09-14 03:59:59                     167.307316                          7.509415                         7.220000                        1.102301                             1294.305558                               -500.098505                             1298.782732                               -499.538897                             1302.730273
# 18364  2017-11-14 06:59:59                     187.228955                          6.981828                         7.350000                        2.485930                             1602.955099                               -500.006878                             1603.124485                               -495.715293                             1598.538718
# 18606  2017-11-24 11:59:59                     218.652631                         10.557150                         6.950000                        2.682433                             1495.258415                               -491.236627                             1497.486291                               -530.060133                             1499.552120
# 15793  2016-11-19 14:59:59                     216.277418                          6.960380                         7.106666                        1.372148                             1604.867374                               -499.373954                             1600.497622                               -499.901005                             1598.263174

# %%
data_all = pd.concat([train_data, test_data, full_data])

# %%
data_all.columns
# Out:
# Index(['date', 'final.output.concentrate_ag', 'final.output.concentrate_pb',
#        'final.output.concentrate_sol', 'final.output.concentrate_au',
#        'final.output.recovery', 'final.output.tail_ag', 'final.output.tail_pb',
#        'final.output.tail_sol', 'final.output.tail_au',
#        'primary_cleaner.input.sulfate', 'primary_cleaner.input.depressant',
#        'primary_cleaner.input.feed_size', 'primary_cleaner.input.xanthate',
#        'primary_cleaner.output.concentrate_ag',
#        'primary_cleaner.output.concentrate_pb',
#        'primary_cleaner.output.concentrate_sol',
#        'primary_cleaner.output.concentrate_au',
#        'primary_cleaner.output.tail_ag', 'primary_cleaner.output.tail_pb',
#        'primary_cleaner.output.tail_sol', 'primary_cleaner.output.tail_au',
#        'primary_cleaner.state.floatbank8_a_air',
#        'primary_cleaner.state.floatbank8_a_level',
#        'primary_cleaner.state.floatbank8_b_air',
#        'primary_cleaner.state.floatbank8_b_level',
#        'primary_cleaner.state.floatbank8_c_air',
#        'primary_cleaner.state.floatbank8_c_level',
#        'primary_cleaner.state.floatbank8_d_air',
#        'primary_cleaner.state.floatbank8_d_level',
#        'rougher.calculation.sulfate_to_au_concentrate',
#        'rougher.calculation.floatbank10_sulfate_to_au_feed',
#        'rougher.calculation.floatbank11_sulfate_to_au_feed',
#        'rougher.calculation.au_pb_ratio', 'rougher.input.feed_ag',
#        'rougher.input.feed_pb', 'rougher.input.feed_rate',
#        'rougher.input.feed_size', 'rougher.input.feed_sol',
#        'rougher.input.feed_au', 'rougher.input.floatbank10_sulfate',
#        'rougher.input.floatbank10_xanthate',
#        'rougher.input.floatbank11_sulfate',
#        'rougher.input.floatbank11_xanthate', 'rougher.output.concentrate_ag',
#        'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol',
#        'rougher.output.concentrate_au', 'rougher.output.recovery',
#        'rougher.output.tail_ag', 'rougher.output.tail_pb',
#        'rougher.output.tail_sol', 'rougher.output.tail_au',
#        'rougher.state.floatbank10_a_air', 'rougher.state.floatbank10_a_level',
#        'rougher.state.floatbank10_b_air', 'rougher.state.floatbank10_b_level',
#        'rougher.state.floatbank10_c_air', 'rougher.state.floatbank10_c_level',
#        'rougher.state.floatbank10_d_air', 'rougher.state.floatbank10_d_level',
#        'rougher.state.floatbank10_e_air', 'rougher.state.floatbank10_e_level',
#        'rougher.state.floatbank10_f_air', 'rougher.state.floatbank10_f_level',
#        'secondary_cleaner.output.tail_ag', 'secondary_cleaner.output.tail_pb',
#        'secondary_cleaner.output.tail_sol', 'secondary_cleaner.output.tail_au',
#        'secondary_cleaner.state.floatbank2_a_air',
#        'secondary_cleaner.state.floatbank2_a_level',
#        'secondary_cleaner.state.floatbank2_b_air',
#        'secondary_cleaner.state.floatbank2_b_level',
#        'secondary_cleaner.state.floatbank3_a_air',
#        'secondary_cleaner.state.floatbank3_a_level',
#        'secondary_cleaner.state.floatbank3_b_air',
#        'secondary_cleaner.state.floatbank3_b_level',
#        'secondary_cleaner.state.floatbank4_a_air',
#        'secondary_cleaner.state.floatbank4_a_level',
#        'secondary_cleaner.state.floatbank4_b_air',
#        'secondary_cleaner.state.floatbank4_b_level',
#        'secondary_cleaner.state.floatbank5_a_air',
#        'secondary_cleaner.state.floatbank5_a_level',
#        'secondary_cleaner.state.floatbank5_b_air',
#        'secondary_cleaner.state.floatbank5_b_level',
#        'secondary_cleaner.state.floatbank6_a_air',
#        'secondary_cleaner.state.floatbank6_a_level'],
#       dtype='object')

# %%
data_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38878 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                38878 non-null  object
#  1   final.output.concentrate_ag                         33586 non-null  float64
#  2   final.output.concentrate_pb                         33586 non-null  float64
#  3   final.output.concentrate_sol                        33166 non-null  float64
#  4   final.output.concentrate_au                         33588 non-null  float64
#  5   final.output.recovery                               33588 non-null  float64
#  6   final.output.tail_ag                                33587 non-null  float64
#  7   final.output.tail_pb                                33387 non-null  float64
#  8   final.output.tail_sol                               33577 non-null  float64
#  9   final.output.tail_au                                33588 non-null  float64
#  10  primary_cleaner.input.sulfate                       38830 non-null  float64
#  11  primary_cleaner.input.depressant                    38804 non-null  float64
#  12  primary_cleaner.input.feed_size                     38878 non-null  float64
#  13  primary_cleaner.input.xanthate                      38670 non-null  float64
#  14  primary_cleaner.output.concentrate_ag               33588 non-null  float64
#  15  primary_cleaner.output.concentrate_pb               33386 non-null  float64
#  16  primary_cleaner.output.concentrate_sol              32932 non-null  float64
#  17  primary_cleaner.output.concentrate_au               33588 non-null  float64
#  18  primary_cleaner.output.tail_ag                      33583 non-null  float64
#  19  primary_cleaner.output.tail_pb                      33552 non-null  float64
#  20  primary_cleaner.output.tail_sol                     33480 non-null  float64
#  21  primary_cleaner.output.tail_au                      33588 non-null  float64
#  22  primary_cleaner.state.floatbank8_a_air              38870 non-null  float64
#  23  primary_cleaner.state.floatbank8_a_level            38876 non-null  float64
#  24  primary_cleaner.state.floatbank8_b_air              38870 non-null  float64
#  25  primary_cleaner.state.floatbank8_b_level            38876 non-null  float64
#  26  primary_cleaner.state.floatbank8_c_air              38874 non-null  float64
#  27  primary_cleaner.state.floatbank8_c_level            38876 non-null  float64
#  28  primary_cleaner.state.floatbank8_d_air              38872 non-null  float64
#  29  primary_cleaner.state.floatbank8_d_level            38876 non-null  float64
#  30  rougher.calculation.sulfate_to_au_concentrate       33585 non-null  float64
#  31  rougher.calculation.floatbank10_sulfate_to_au_feed  33585 non-null  float64
#  32  rougher.calculation.floatbank11_sulfate_to_au_feed  33585 non-null  float64
#  33  rougher.calculation.au_pb_ratio                     33588 non-null  float64
#  34  rougher.input.feed_ag                               38878 non-null  float64
#  35  rougher.input.feed_pb                               38678 non-null  float64
#  36  rougher.input.feed_rate                             38856 non-null  float64
#  37  rougher.input.feed_size                             38588 non-null  float64
#  38  rougher.input.feed_sol                              38680 non-null  float64
#  39  rougher.input.feed_au                               38878 non-null  float64
#  40  rougher.input.floatbank10_sulfate                   38810 non-null  float64
#  41  rougher.input.floatbank10_xanthate                  38862 non-null  float64
#  42  rougher.input.floatbank11_sulfate                   38790 non-null  float64
#  43  rougher.input.floatbank11_xanthate                  37972 non-null  float64
#  44  rougher.output.concentrate_ag                       33588 non-null  float64
#  45  rougher.output.concentrate_pb                       33588 non-null  float64
#  46  rougher.output.concentrate_sol                      33543 non-null  float64
#  47  rougher.output.concentrate_au                       33588 non-null  float64
#  48  rougher.output.recovery                             33588 non-null  float64
#  49  rougher.output.tail_ag                              33586 non-null  float64
#  50  rougher.output.tail_pb                              33588 non-null  float64
#  51  rougher.output.tail_sol                             33588 non-null  float64
#  52  rougher.output.tail_au                              33588 non-null  float64
#  53  rougher.state.floatbank10_a_air                     38876 non-null  float64
#  54  rougher.state.floatbank10_a_level                   38876 non-null  float64
#  55  rougher.state.floatbank10_b_air                     38876 non-null  float64
#  56  rougher.state.floatbank10_b_level                   38876 non-null  float64
#  57  rougher.state.floatbank10_c_air                     38876 non-null  float64
#  58  rougher.state.floatbank10_c_level                   38876 non-null  float64
#  59  rougher.state.floatbank10_d_air                     38878 non-null  float64
#  60  rougher.state.floatbank10_d_level                   38878 non-null  float64
#  61  rougher.state.floatbank10_e_air                     38006 non-null  float64
#  62  rougher.state.floatbank10_e_level                   38878 non-null  float64
#  63  rougher.state.floatbank10_f_air                     38878 non-null  float64
#  64  rougher.state.floatbank10_f_level                   38878 non-null  float64
#  65  secondary_cleaner.output.tail_ag                    33584 non-null  float64
#  66  secondary_cleaner.output.tail_pb                    33566 non-null  float64
#  67  secondary_cleaner.output.tail_sol                   30235 non-null  float64
#  68  secondary_cleaner.output.tail_au                    33588 non-null  float64
#  69  secondary_cleaner.state.floatbank2_a_air            38438 non-null  float64
#  70  secondary_cleaner.state.floatbank2_a_level          38876 non-null  float64
#  71  secondary_cleaner.state.floatbank2_b_air            38832 non-null  float64
#  72  secondary_cleaner.state.floatbank2_b_level          38876 non-null  float64
#  73  secondary_cleaner.state.floatbank3_a_air            38852 non-null  float64
#  74  secondary_cleaner.state.floatbank3_a_level          38876 non-null  float64
#  75  secondary_cleaner.state.floatbank3_b_air            38876 non-null  float64
#  76  secondary_cleaner.state.floatbank3_b_level          38876 non-null  float64
#  77  secondary_cleaner.state.floatbank4_a_air            38866 non-null  float64
#  78  secondary_cleaner.state.floatbank4_a_level          38876 non-null  float64
#  79  secondary_cleaner.state.floatbank4_b_air            38876 non-null  float64
#  80  secondary_cleaner.state.floatbank4_b_level          38876 non-null  float64
#  81  secondary_cleaner.state.floatbank5_a_air            38876 non-null  float64
#  82  secondary_cleaner.state.floatbank5_a_level          38876 non-null  float64
#  83  secondary_cleaner.state.floatbank5_b_air            38876 non-null  float64
#  84  secondary_cleaner.state.floatbank5_b_level          38876 non-null  float64
#  85  secondary_cleaner.state.floatbank6_a_air            38874 non-null  float64
#  86  secondary_cleaner.state.floatbank6_a_level          38876 non-null  float64
# dtypes: float64(86), object(1)
# memory usage: 26.1+ MB

# %%
train_data.merge(full_data[['date', 'final.output.recovery', 'rougher.output.recovery']], how = 'left', on='date')
# Out:
#                       date  final.output.concentrate_ag  \
# 0      2016-01-15 00:00:00                     6.055403
# 1      2016-01-15 01:00:00                     6.029369
# 2      2016-01-15 02:00:00                     6.055926
# 3      2016-01-15 03:00:00                     6.047977
# 4      2016-01-15 04:00:00                     6.148599
# ...                    ...                          ...
# 14144  2018-08-18 06:59:59                     3.224920
# 14145  2018-08-18 07:59:59                     3.195978
# 14146  2018-08-18 08:59:59                     3.109998
# 14147  2018-08-18 09:59:59                     3.367241
# 14148  2018-08-18 10:59:59                     3.598375
#
#        final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                         9.889648                      5.507324
# 1                         9.968944                      5.257781
# 2                        10.213995                      5.383759
# 3                         9.977019                      4.858634
# 4                        10.142511                      4.939416
# ...                            ...                           ...
# 14144                    11.356233                      6.803482
# 14145                    11.349355                      6.862249
# 14146                    11.434366                      6.886013
# 14147                    11.625587                      6.799433
# 14148                    11.737832                      6.717509
#
#        final.output.concentrate_au  final.output.recovery_x  \
# 0                        42.192020                70.541216
# 1                        42.701629                69.266198
# 2                        42.657501                68.116445
# 3                        42.689819                68.347543
# 4                        42.774141                66.927016
# ...                            ...                      ...
# 14144                    46.713954                73.755150
# 14145                    46.866780                69.049291
# 14146                    46.795691                67.002189
# 14147                    46.408188                65.523246
# 14148                    46.299438                70.281454
#
#        final.output.tail_ag  final.output.tail_pb  final.output.tail_sol  \
# 0                 10.411962              0.895447              16.904297
# 1                 10.462676              0.927452              16.634514
# 2                 10.507046              0.953716              16.208849
# 3                 10.422762              0.883763              16.532835
# 4                 10.360302              0.792826              16.525686
# ...                     ...                   ...                    ...
# 14144              8.769645              3.141541              10.403181
# 14145              8.897321              3.130493              10.549470
# 14146              8.529606              2.911418              11.115147
# 14147              8.777171              2.819214              10.463847
# 14148              8.406690              2.517518              10.652193
#
#        final.output.tail_au  ...  secondary_cleaner.state.floatbank4_b_air  \
# 0                  2.143149  ...                                 12.099931
# 1                  2.224930  ...                                 11.950531
# 2                  2.257889  ...                                 11.912783
# 3                  2.146849  ...                                 11.999550
# 4                  2.055292  ...                                 11.953070
# ...                     ...  ...                                       ...
# 14144              1.529220  ...                                 20.007571
# 14145              1.612542  ...                                 20.035660
# 14146              1.596616  ...                                 19.951231
# 14147              1.602879  ...                                 20.054122
# 14148              1.389434  ...                                 20.020205
#
#        secondary_cleaner.state.floatbank4_b_level  \
# 0                                     -504.715942
# 1                                     -501.331529
# 2                                     -501.133383
# 3                                     -501.193686
# 4                                     -501.053894
# ...                                           ...
# 14144                                 -499.740028
# 14145                                 -500.251357
# 14146                                 -499.857027
# 14147                                 -500.314711
# 14148                                 -500.220296
#
#        secondary_cleaner.state.floatbank5_a_air  \
# 0                                      9.925633
# 1                                     10.039245
# 2                                     10.070913
# 3                                      9.970366
# 4                                      9.925709
# ...                                         ...
# 14144                                 18.006038
# 14145                                 17.998535
# 14146                                 18.019543
# 14147                                 17.979515
# 14148                                 17.963512
#
#        secondary_cleaner.state.floatbank5_a_level  \
# 0                                     -498.310211
# 1                                     -500.169983
# 2                                     -500.129135
# 3                                     -499.201640
# 4                                     -501.686727
# ...                                           ...
# 14144                                 -499.834374
# 14145                                 -500.395178
# 14146                                 -500.451156
# 14147                                 -499.272871
# 14148                                 -499.939490
#
#        secondary_cleaner.state.floatbank5_b_air  \
# 0                                      8.079666
# 1                                      7.984757
# 2                                      8.013877
# 3                                      7.977324
# 4                                      7.894242
# ...                                         ...
# 14144                                 13.001114
# 14145                                 12.954048
# 14146                                 13.023431
# 14147                                 12.992404
# 14148                                 12.990306
#
#        secondary_cleaner.state.floatbank5_b_level  \
# 0                                     -500.470978
# 1                                     -500.582168
# 2                                     -500.517572
# 3                                     -500.255908
# 4                                     -500.356035
# ...                                           ...
# 14144                                 -500.155694
# 14145                                 -499.895163
# 14146                                 -499.914391
# 14147                                 -499.976268
# 14148                                 -500.080993
#
#        secondary_cleaner.state.floatbank6_a_air  \
# 0                                     14.151341
# 1                                     13.998353
# 2                                     14.028663
# 3                                     14.005551
# 4                                     13.996647
# ...                                         ...
# 14144                                 20.007840
# 14145                                 19.968498
# 14146                                 19.990885
# 14147                                 20.013986
# 14148                                 19.990336
#
#        secondary_cleaner.state.floatbank6_a_level  final.output.recovery_y  \
# 0                                     -605.841980                70.541216
# 1                                     -599.787184                69.266198
# 2                                     -601.427363                68.116445
# 3                                     -599.996129                68.347543
# 4                                     -601.496691                66.927016
# ...                                           ...                      ...
# 14144                                 -501.296428                73.755150
# 14145                                 -501.041608                69.049291
# 14146                                 -501.518452                67.002189
# 14147                                 -500.625471                65.523246
# 14148                                 -499.191575                70.281454
#
#        rougher.output.recovery_y
# 0                      87.107763
# 1                      86.843261
# 2                      86.842308
# 3                      87.226430
# 4                      86.688794
# ...                          ...
# 14144                  89.574376
# 14145                  87.724007
# 14146                  88.890579
# 14147                  89.858126
# 14148                  89.514960
#
# [14149 rows x 89 columns]

# %%
# определим столбцы, которых нет в тестовой выборке
col_not_in_test = set(train_data.columns) - set(test_data.columns)
col_not_in_test
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
#  'rougher.output.tail_ag',
#  'rougher.output.tail_au',
#  'rougher.output.tail_pb',
#  'rougher.output.tail_sol',
#  'secondary_cleaner.output.tail_ag',
#  'secondary_cleaner.output.tail_au',
#  'secondary_cleaner.output.tail_pb',
#  'secondary_cleaner.output.tail_sol'}

# %% [markdown]
# **Вывод**
#
# Исходя из полученного списка столбцов видим, что в тестовых данных не хватает тех признаков, которые по тех. процессу не могут быть посчитаны до получения финальных сплавов. В виду этого подобные признаки также не должны быть использованы при обучении модели. Т.е. перед созданием модели их нужно убрать из обучающей выборки. Исключение составляют два целевых признака - ***final.output.recovery, rougher.output.recovery***.

# %% [markdown]
# ### Удалим признаки из обучающей выборки

# %% [markdown]
# - Данные train_data и full_data объединены, и датасет train_data является максимально полным.
# - Теперь необходимо удалить столбцы, которых нет в test_data и которые нельзя использовать при обучении. **Это будет финальная выборка для построения модели,** которая будет использоваться для деления на подвыборки методом test_train_split.
# - **!!! Оставляем в train_data целевые метки -  'rougher.output.recovery' и  'final.output.recovery'.**

# %% [markdown]
# Столбцы, которые есть в обучающих, но отсутствуют в тестовых данных:
#
# ```
# 'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
#  'rougher.output.tail_ag',
#  'rougher.output.tail_au',
#  'rougher.output.tail_pb',
#  'rougher.output.tail_sol',
#  'secondary_cleaner.output.tail_ag',
#  'secondary_cleaner.output.tail_au',
#  'secondary_cleaner.output.tail_pb',
#  'secondary_cleaner.output.tail_sol'
#
# ```

# %%
df_train = train_data.drop(columns=[
    'final.output.concentrate_ag',
 'final.output.concentrate_au',
 'final.output.concentrate_pb',
 'final.output.concentrate_sol',
 'final.output.tail_ag',
 'final.output.tail_au',
 'final.output.tail_pb',
 'final.output.tail_sol',
 'primary_cleaner.output.concentrate_ag',
 'primary_cleaner.output.concentrate_au',
 'primary_cleaner.output.concentrate_pb',
 'primary_cleaner.output.concentrate_sol',
 'primary_cleaner.output.tail_ag',
 'primary_cleaner.output.tail_au',
 'primary_cleaner.output.tail_pb',
 'primary_cleaner.output.tail_sol',
 'rougher.calculation.au_pb_ratio',
 'rougher.calculation.floatbank10_sulfate_to_au_feed',
 'rougher.calculation.floatbank11_sulfate_to_au_feed',
 'rougher.calculation.sulfate_to_au_concentrate',
 'rougher.output.concentrate_ag',
 'rougher.output.concentrate_au',
 'rougher.output.concentrate_pb',
 'rougher.output.concentrate_sol',
 'rougher.output.tail_ag',
 'rougher.output.tail_au',
 'rougher.output.tail_pb',
 'rougher.output.tail_sol',
 'secondary_cleaner.output.tail_ag',
 'secondary_cleaner.output.tail_au',
 'secondary_cleaner.output.tail_pb',
 'secondary_cleaner.output.tail_sol'
])

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12344 entries, 0 to 14148
# Data columns (total 55 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        12344 non-null  object
#  1   final.output.recovery                       12344 non-null  float64
#  2   primary_cleaner.input.sulfate               12344 non-null  float64
#  3   primary_cleaner.input.depressant            12335 non-null  float64
#  4   primary_cleaner.input.feed_size             12344 non-null  float64
#  5   primary_cleaner.input.xanthate              12344 non-null  float64
#  6   primary_cleaner.state.floatbank8_a_air      12344 non-null  float64
#  7   primary_cleaner.state.floatbank8_a_level    12344 non-null  float64
#  8   primary_cleaner.state.floatbank8_b_air      12344 non-null  float64
#  9   primary_cleaner.state.floatbank8_b_level    12344 non-null  float64
#  10  primary_cleaner.state.floatbank8_c_air      12343 non-null  float64
#  11  primary_cleaner.state.floatbank8_c_level    12344 non-null  float64
#  12  primary_cleaner.state.floatbank8_d_air      12342 non-null  float64
#  13  primary_cleaner.state.floatbank8_d_level    12344 non-null  float64
#  14  rougher.input.feed_ag                       12344 non-null  float64
#  15  rougher.input.feed_pb                       12344 non-null  float64
#  16  rougher.input.feed_rate                     12341 non-null  float64
#  17  rougher.input.feed_size                     12344 non-null  float64
#  18  rougher.input.feed_sol                      12344 non-null  float64
#  19  rougher.input.feed_au                       12344 non-null  float64
#  20  rougher.input.floatbank10_sulfate           12340 non-null  float64
#  21  rougher.input.floatbank10_xanthate          12344 non-null  float64
#  22  rougher.input.floatbank11_sulfate           12331 non-null  float64
#  23  rougher.input.floatbank11_xanthate          12344 non-null  float64
#  24  rougher.output.recovery                     12344 non-null  float64
#  25  rougher.state.floatbank10_a_air             12344 non-null  float64
#  26  rougher.state.floatbank10_a_level           12344 non-null  float64
#  27  rougher.state.floatbank10_b_air             12344 non-null  float64
#  28  rougher.state.floatbank10_b_level           12344 non-null  float64
#  29  rougher.state.floatbank10_c_air             12344 non-null  float64
#  30  rougher.state.floatbank10_c_level           12344 non-null  float64
#  31  rougher.state.floatbank10_d_air             12344 non-null  float64
#  32  rougher.state.floatbank10_d_level           12344 non-null  float64
#  33  rougher.state.floatbank10_e_air             12344 non-null  float64
#  34  rougher.state.floatbank10_e_level           12344 non-null  float64
#  35  rougher.state.floatbank10_f_air             12344 non-null  float64
#  36  rougher.state.floatbank10_f_level           12344 non-null  float64
#  37  secondary_cleaner.state.floatbank2_a_air    12344 non-null  float64
#  38  secondary_cleaner.state.floatbank2_a_level  12344 non-null  float64
#  39  secondary_cleaner.state.floatbank2_b_air    12343 non-null  float64
#  40  secondary_cleaner.state.floatbank2_b_level  12344 non-null  float64
#  41  secondary_cleaner.state.floatbank3_a_air    12343 non-null  float64
#  42  secondary_cleaner.state.floatbank3_a_level  12344 non-null  float64
#  43  secondary_cleaner.state.floatbank3_b_air    12344 non-null  float64
#  44  secondary_cleaner.state.floatbank3_b_level  12344 non-null  float64
#  45  secondary_cleaner.state.floatbank4_a_air    12340 non-null  float64
#  46  secondary_cleaner.state.floatbank4_a_level  12344 non-null  float64
#  47  secondary_cleaner.state.floatbank4_b_air    12344 non-null  float64
#  48  secondary_cleaner.state.floatbank4_b_level  12344 non-null  float64
#  49  secondary_cleaner.state.floatbank5_a_air    12344 non-null  float64
#  50  secondary_cleaner.state.floatbank5_a_level  12344 non-null  float64
#  51  secondary_cleaner.state.floatbank5_b_air    12344 non-null  float64
#  52  secondary_cleaner.state.floatbank5_b_level  12344 non-null  float64
#  53  secondary_cleaner.state.floatbank6_a_air    12344 non-null  float64
#  54  secondary_cleaner.state.floatbank6_a_level  12344 non-null  float64
# dtypes: float64(54), object(1)
# memory usage: 5.3+ MB

# %%
df_train['rougher.output.recovery'].describe()
# Out:
# count    12344.000000
# mean        83.288285
# std         13.147377
# min          0.000000
# 25%         80.335209
# 50%         85.408497
# 75%         90.006827
# max        100.000000
# Name: rougher.output.recovery, dtype: float64

# %%
df_train['final.output.recovery'].describe()
# Out:
# count    12344.000000
# mean        66.942540
# std          8.905748
# min          0.000000
# 25%         63.088417
# 50%         67.527722
# 75%         72.280415
# max        100.000000
# Name: final.output.recovery, dtype: float64

# %%
df_train.shape
# Out:
# (12344, 55)

# %%
# финальная проверка на дубликаты
df_train.duplicated().sum()
# Out:
# 0

# %%
df_train = df_train.dropna(subset=[
        'date', 
    'final.output.recovery', 
    'primary_cleaner.input.sulfate',
       'primary_cleaner.input.depressant', 'primary_cleaner.input.feed_size',
       'primary_cleaner.input.xanthate',
       'primary_cleaner.state.floatbank8_a_air',
       'primary_cleaner.state.floatbank8_a_level',
       'primary_cleaner.state.floatbank8_b_air',
       'primary_cleaner.state.floatbank8_b_level',
       'primary_cleaner.state.floatbank8_c_air',
       'primary_cleaner.state.floatbank8_c_level',
       'primary_cleaner.state.floatbank8_d_air',
       'primary_cleaner.state.floatbank8_d_level', 'rougher.input.feed_ag',
       'rougher.input.feed_pb', 'rougher.input.feed_rate',
       'rougher.input.feed_size', 'rougher.input.feed_sol',
       'rougher.input.feed_au', 'rougher.input.floatbank10_sulfate',
       'rougher.input.floatbank10_xanthate',
       'rougher.input.floatbank11_sulfate',
       'rougher.input.floatbank11_xanthate', 'rougher.output.recovery',
       'rougher.state.floatbank10_a_air', 'rougher.state.floatbank10_a_level',
       'rougher.state.floatbank10_b_air', 'rougher.state.floatbank10_b_level',
       'rougher.state.floatbank10_c_air', 'rougher.state.floatbank10_c_level',
       'rougher.state.floatbank10_d_air', 'rougher.state.floatbank10_d_level',
       'rougher.state.floatbank10_e_air', 'rougher.state.floatbank10_e_level',
       'rougher.state.floatbank10_f_air', 'rougher.state.floatbank10_f_level',
       'secondary_cleaner.state.floatbank2_a_air',
       'secondary_cleaner.state.floatbank2_a_level',
       'secondary_cleaner.state.floatbank2_b_air',
       'secondary_cleaner.state.floatbank2_b_level',
       'secondary_cleaner.state.floatbank3_a_air',
       'secondary_cleaner.state.floatbank3_a_level',
       'secondary_cleaner.state.floatbank3_b_air',
       'secondary_cleaner.state.floatbank3_b_level',
       'secondary_cleaner.state.floatbank4_a_air',
       'secondary_cleaner.state.floatbank4_a_level',
       'secondary_cleaner.state.floatbank4_b_air',
       'secondary_cleaner.state.floatbank4_b_level',
       'secondary_cleaner.state.floatbank5_a_air',
       'secondary_cleaner.state.floatbank5_a_level',
       'secondary_cleaner.state.floatbank5_b_air',
       'secondary_cleaner.state.floatbank5_b_level',
       'secondary_cleaner.state.floatbank6_a_air',
       'secondary_cleaner.state.floatbank6_a_level'
])

# %% [markdown]
# **Путем очистки и объединения трех исходных датасетов получен финальный датасет df_train, который будет использоваться для формирования подвыборок и построения модели.**

# %% [markdown]
# ### Добавим в исходные тестовые данные test data целевые признаки final.output.recovery, rougher.output.recovery из полных данных

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5241 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5241 non-null   object
#  1   primary_cleaner.input.sulfate               5240 non-null   float64
#  2   primary_cleaner.input.depressant            5240 non-null   float64
#  3   primary_cleaner.input.feed_size             5241 non-null   float64
#  4   primary_cleaner.input.xanthate              5241 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5241 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5241 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5241 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5241 non-null   float64
#  9   primary_cleaner.state.floatbank8_c_air      5241 non-null   float64
#  10  primary_cleaner.state.floatbank8_c_level    5241 non-null   float64
#  11  primary_cleaner.state.floatbank8_d_air      5241 non-null   float64
#  12  primary_cleaner.state.floatbank8_d_level    5241 non-null   float64
#  13  rougher.input.feed_ag                       5241 non-null   float64
#  14  rougher.input.feed_pb                       5241 non-null   float64
#  15  rougher.input.feed_rate                     5240 non-null   float64
#  16  rougher.input.feed_size                     5241 non-null   float64
#  17  rougher.input.feed_sol                      5241 non-null   float64
#  18  rougher.input.feed_au                       5241 non-null   float64
#  19  rougher.input.floatbank10_sulfate           5241 non-null   float64
#  20  rougher.input.floatbank10_xanthate          5241 non-null   float64
#  21  rougher.input.floatbank11_sulfate           5241 non-null   float64
#  22  rougher.input.floatbank11_xanthate          5241 non-null   float64
#  23  rougher.state.floatbank10_a_air             5241 non-null   float64
#  24  rougher.state.floatbank10_a_level           5241 non-null   float64
#  25  rougher.state.floatbank10_b_air             5241 non-null   float64
#  26  rougher.state.floatbank10_b_level           5241 non-null   float64
#  27  rougher.state.floatbank10_c_air             5241 non-null   float64
#  28  rougher.state.floatbank10_c_level           5241 non-null   float64
#  29  rougher.state.floatbank10_d_air             5241 non-null   float64
#  30  rougher.state.floatbank10_d_level           5241 non-null   float64
#  31  rougher.state.floatbank10_e_air             5241 non-null   float64
#  32  rougher.state.floatbank10_e_level           5241 non-null   float64
#  33  rougher.state.floatbank10_f_air             5241 non-null   float64
#  34  rougher.state.floatbank10_f_level           5241 non-null   float64
#  35  secondary_cleaner.state.floatbank2_a_air    5241 non-null   float64
#  36  secondary_cleaner.state.floatbank2_a_level  5241 non-null   float64
#  37  secondary_cleaner.state.floatbank2_b_air    5239 non-null   float64
#  38  secondary_cleaner.state.floatbank2_b_level  5241 non-null   float64
#  39  secondary_cleaner.state.floatbank3_a_air    5232 non-null   float64
#  40  secondary_cleaner.state.floatbank3_a_level  5241 non-null   float64
#  41  secondary_cleaner.state.floatbank3_b_air    5241 non-null   float64
#  42  secondary_cleaner.state.floatbank3_b_level  5241 non-null   float64
#  43  secondary_cleaner.state.floatbank4_a_air    5241 non-null   float64
#  44  secondary_cleaner.state.floatbank4_a_level  5241 non-null   float64
#  45  secondary_cleaner.state.floatbank4_b_air    5241 non-null   float64
#  46  secondary_cleaner.state.floatbank4_b_level  5241 non-null   float64
#  47  secondary_cleaner.state.floatbank5_a_air    5241 non-null   float64
#  48  secondary_cleaner.state.floatbank5_a_level  5241 non-null   float64
#  49  secondary_cleaner.state.floatbank5_b_air    5241 non-null   float64
#  50  secondary_cleaner.state.floatbank5_b_level  5241 non-null   float64
#  51  secondary_cleaner.state.floatbank6_a_air    5241 non-null   float64
#  52  secondary_cleaner.state.floatbank6_a_level  5241 non-null   float64
# dtypes: float64(52), object(1)
# memory usage: 2.2+ MB

# %%
test_data.columns
# Out:
# Index(['date', 'primary_cleaner.input.sulfate',
#        'primary_cleaner.input.depressant', 'primary_cleaner.input.feed_size',
#        'primary_cleaner.input.xanthate',
#        'primary_cleaner.state.floatbank8_a_air',
#        'primary_cleaner.state.floatbank8_a_level',
#        'primary_cleaner.state.floatbank8_b_air',
#        'primary_cleaner.state.floatbank8_b_level',
#        'primary_cleaner.state.floatbank8_c_air',
#        'primary_cleaner.state.floatbank8_c_level',
#        'primary_cleaner.state.floatbank8_d_air',
#        'primary_cleaner.state.floatbank8_d_level', 'rougher.input.feed_ag',
#        'rougher.input.feed_pb', 'rougher.input.feed_rate',
#        'rougher.input.feed_size', 'rougher.input.feed_sol',
#        'rougher.input.feed_au', 'rougher.input.floatbank10_sulfate',
#        'rougher.input.floatbank10_xanthate',
#        'rougher.input.floatbank11_sulfate',
#        'rougher.input.floatbank11_xanthate', 'rougher.state.floatbank10_a_air',
#        'rougher.state.floatbank10_a_level', 'rougher.state.floatbank10_b_air',
#        'rougher.state.floatbank10_b_level', 'rougher.state.floatbank10_c_air',
#        'rougher.state.floatbank10_c_level', 'rougher.state.floatbank10_d_air',
#        'rougher.state.floatbank10_d_level', 'rougher.state.floatbank10_e_air',
#        'rougher.state.floatbank10_e_level', 'rougher.state.floatbank10_f_air',
#        'rougher.state.floatbank10_f_level',
#        'secondary_cleaner.state.floatbank2_a_air',
#        'secondary_cleaner.state.floatbank2_a_level',
#        'secondary_cleaner.state.floatbank2_b_air',
#        'secondary_cleaner.state.floatbank2_b_level',
#        'secondary_cleaner.state.floatbank3_a_air',
#        'secondary_cleaner.state.floatbank3_a_level',
#        'secondary_cleaner.state.floatbank3_b_air',
#        'secondary_cleaner.state.floatbank3_b_level',
#        'secondary_cleaner.state.floatbank4_a_air',
#        'secondary_cleaner.state.floatbank4_a_level',
#        'secondary_cleaner.state.floatbank4_b_air',
#        'secondary_cleaner.state.floatbank4_b_level',
#        'secondary_cleaner.state.floatbank5_a_air',
#        'secondary_cleaner.state.floatbank5_a_level',
#        'secondary_cleaner.state.floatbank5_b_air',
#        'secondary_cleaner.state.floatbank5_b_level',
#        'secondary_cleaner.state.floatbank6_a_air',
#        'secondary_cleaner.state.floatbank6_a_level'],
#       dtype='object')

# %%
len(test_data.columns)
# Out:
# 53

# %%
# удалим пропущенные значения, так как они составляют менее 1%
test_data = test_data.dropna(subset=[
    'date', 'primary_cleaner.input.sulfate',
       'primary_cleaner.input.depressant', 'primary_cleaner.input.feed_size',
       'primary_cleaner.input.xanthate',
       'primary_cleaner.state.floatbank8_a_air',
       'primary_cleaner.state.floatbank8_a_level',
       'primary_cleaner.state.floatbank8_b_air',
       'primary_cleaner.state.floatbank8_b_level',
       'primary_cleaner.state.floatbank8_c_air',
       'primary_cleaner.state.floatbank8_c_level',
       'primary_cleaner.state.floatbank8_d_air',
       'primary_cleaner.state.floatbank8_d_level', 'rougher.input.feed_ag',
       'rougher.input.feed_pb', 'rougher.input.feed_rate',
       'rougher.input.feed_size', 'rougher.input.feed_sol',
       'rougher.input.feed_au', 'rougher.input.floatbank10_sulfate',
       'rougher.input.floatbank10_xanthate',
       'rougher.input.floatbank11_sulfate',
       'rougher.input.floatbank11_xanthate', 'rougher.state.floatbank10_a_air',
       'rougher.state.floatbank10_a_level', 'rougher.state.floatbank10_b_air',
       'rougher.state.floatbank10_b_level', 'rougher.state.floatbank10_c_air',
       'rougher.state.floatbank10_c_level', 'rougher.state.floatbank10_d_air',
       'rougher.state.floatbank10_d_level', 'rougher.state.floatbank10_e_air',
       'rougher.state.floatbank10_e_level', 'rougher.state.floatbank10_f_air',
       'rougher.state.floatbank10_f_level',
       'secondary_cleaner.state.floatbank2_a_air',
       'secondary_cleaner.state.floatbank2_a_level',
       'secondary_cleaner.state.floatbank2_b_air',
       'secondary_cleaner.state.floatbank2_b_level',
       'secondary_cleaner.state.floatbank3_a_air',
       'secondary_cleaner.state.floatbank3_a_level',
       'secondary_cleaner.state.floatbank3_b_air',
       'secondary_cleaner.state.floatbank3_b_level',
       'secondary_cleaner.state.floatbank4_a_air',
       'secondary_cleaner.state.floatbank4_a_level',
       'secondary_cleaner.state.floatbank4_b_air',
       'secondary_cleaner.state.floatbank4_b_level',
       'secondary_cleaner.state.floatbank5_a_air',
       'secondary_cleaner.state.floatbank5_a_level',
       'secondary_cleaner.state.floatbank5_b_air',
       'secondary_cleaner.state.floatbank5_b_level',
       'secondary_cleaner.state.floatbank6_a_air',
       'secondary_cleaner.state.floatbank6_a_level'
])

# %%
# финальная проверка на дубликаты
test_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Теперь необходимо добавить целевые признаки в тестовую выборку из full_data.

# %%
df_test = test_data.merge(full_data[['date', 'final.output.recovery', 'rougher.output.recovery']], how = 'outer', on='date')

# %%
df_test.columns
# Out:
# Index(['date', 'primary_cleaner.input.sulfate',
#        'primary_cleaner.input.depressant', 'primary_cleaner.input.feed_size',
#        'primary_cleaner.input.xanthate',
#        'primary_cleaner.state.floatbank8_a_air',
#        'primary_cleaner.state.floatbank8_a_level',
#        'primary_cleaner.state.floatbank8_b_air',
#        'primary_cleaner.state.floatbank8_b_level',
#        'primary_cleaner.state.floatbank8_c_air',
#        'primary_cleaner.state.floatbank8_c_level',
#        'primary_cleaner.state.floatbank8_d_air',
#        'primary_cleaner.state.floatbank8_d_level', 'rougher.input.feed_ag',
#        'rougher.input.feed_pb', 'rougher.input.feed_rate',
#        'rougher.input.feed_size', 'rougher.input.feed_sol',
#        'rougher.input.feed_au', 'rougher.input.floatbank10_sulfate',
#        'rougher.input.floatbank10_xanthate',
#        'rougher.input.floatbank11_sulfate',
#        'rougher.input.floatbank11_xanthate', 'rougher.state.floatbank10_a_air',
#        'rougher.state.floatbank10_a_level', 'rougher.state.floatbank10_b_air',
#        'rougher.state.floatbank10_b_level', 'rougher.state.floatbank10_c_air',
#        'rougher.state.floatbank10_c_level', 'rougher.state.floatbank10_d_air',
#        'rougher.state.floatbank10_d_level', 'rougher.state.floatbank10_e_air',
#        'rougher.state.floatbank10_e_level', 'rougher.state.floatbank10_f_air',
#        'rougher.state.floatbank10_f_level',
#        'secondary_cleaner.state.floatbank2_a_air',
#        'secondary_cleaner.state.floatbank2_a_level',
#        'secondary_cleaner.state.floatbank2_b_air',
#        'secondary_cleaner.state.floatbank2_b_level',
#        'secondary_cleaner.state.floatbank3_a_air',
#        'secondary_cleaner.state.floatbank3_a_level',
#        'secondary_cleaner.state.floatbank3_b_air',
#        'secondary_cleaner.state.floatbank3_b_level',
#        'secondary_cleaner.state.floatbank4_a_air',
#        'secondary_cleaner.state.floatbank4_a_level',
#        'secondary_cleaner.state.floatbank4_b_air',
#        'secondary_cleaner.state.floatbank4_b_level',
#        'secondary_cleaner.state.floatbank5_a_air',
#        'secondary_cleaner.state.floatbank5_a_level',
#        'secondary_cleaner.state.floatbank5_b_air',
#        'secondary_cleaner.state.floatbank5_b_level',
#        'secondary_cleaner.state.floatbank6_a_air',
#        'secondary_cleaner.state.floatbank6_a_level', 'final.output.recovery',
#        'rougher.output.recovery'],
#       dtype='object')

# %%
len(df_test.columns)
# Out:
# 55

# %% [markdown]
# ### Проверим, что эффективность обогащения рассчитана верно

# %% [markdown]
# Прежде чем приступать к моделированию и обучению модели, необходимо убедиться, что модель будет учиться на корректных образцах.
#
# Для этого необходимо вручную посчитать по формуле **эффективность обогащения** и посмотреть величину MAE между значениями в данных и расчетными величинами. Если MAE приемлема, то можно переходить к обучению.

# %% [markdown]
# **Эффективность обогащения рассчитывается по формуле:**
#
#  ![image-2.png](attachment:image-2.png)
#
# где:
# - Recovery = rougher.output.recovery
#
# - C — доля золота в концентрате после флотации/очистки (например, rougher.output.concentrate_au);
#
# - F — доля золота в сырье/концентрате до флотации/очистки (например, rougher.input.feed_au);
#
# - T — доля золота в отвальных хвостах после флотации/очистки (например, rougher.output.tail_au).
# Для прогноза коэффициента нужно найти долю золота в концентратах и хвостах. Причём важен не только финальный продукт, но и черновой концентрат.

# %%
# выделим нужные столбцы для расчета Recovery и MAE
rougher_mae = ['rougher.output.recovery', 
               'rougher.output.concentrate_au', 
               'rougher.input.feed_au', 
               'rougher.output.tail_au'
              ]

# создадим датасет для проверки
recovery = train_data[rougher_mae]
recovery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12344 entries, 0 to 14148
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   rougher.output.recovery        12344 non-null  float64
#  1   rougher.output.concentrate_au  12344 non-null  float64
#  2   rougher.input.feed_au          12344 non-null  float64
#  3   rougher.output.tail_au         12344 non-null  float64
# dtypes: float64(4)
# memory usage: 482.2 KB

# %% [markdown]
# Рассчитаем в отдельном столбце значение эффективности, а затем - сравним его с исходными данными. Для наглядности также рассчитаем средние значение исходной и расчетной эффективности, чтобы убедиться, что они примерно равны.

# %%
recovery['recovery'] = (recovery['rougher.output.concentrate_au'] * \
                        (recovery['rougher.input.feed_au']- recovery['rougher.output.tail_au'])) / \
                        (recovery['rougher.input.feed_au']*(recovery['rougher.output.concentrate_au']- \
                        recovery['rougher.output.tail_au'])) * 100
print('Ошибка MAE составила: ', mean_absolute_error(recovery['rougher.output.recovery'], recovery['recovery']))
print()
print("Среднее значение расчетного значения эффективности обогащения: {}".format(recovery['recovery'].mean()))
print("Среднее значение исходного значения эффективности обогащения: {}".format(recovery['rougher.output.recovery'].mean()))
# Out:
# Ошибка MAE составила:  9.811694914451383e-15
#
# Среднее значение расчетного значения эффективности обогащения: 83.28828452604479
# Среднее значение исходного значения эффективности обогащения: 83.28828452604479

# %% [markdown]
# ***Вывод***: Как видим, MAE незначима и ею можно бренебречь. Кроме того, видим, что средние значения расчетной и исходной эффективности одинаковы.

# %% [markdown]
# ### Изучим целевые значения в df_train датасете, который будет использован для моделирования

# %%
df_train['rougher.output.recovery'].hist(bins=35, alpha=0.5, color='darkblue', figsize=(17, 6))
df_train['final.output.recovery'].hist(bins=35, alpha=0.5, color='red', figsize=(19, 6));

# %%
import seaborn as sns
data_temp, y = df_train, 'rougher.output.recovery'
data_temp_2, y_2 = df_train, 'final.output.recovery'

plt.figure(figsize=(15, 7))
# sns.set(style="darkgrid")
(sns.boxplot(data = data_temp, y = y, color='skyblue')
    .set(title = 'Эффективность обогащения золота', xlabel = 'Целевой признак', ylabel = 'Эффективность,%', ylim=(50, 110)))

(sns.boxplot(data = data_temp_2, y = y_2, color='yellow')
    .set(title = 'Эффективность обогащения золота', xlabel = 'Целевой признак', ylabel = 'Эффективность, %', ylim=(50, 110)))
plt.show()

# %% [markdown]
# **Видим, что данные содержат выбросы.** Изучим описательные статистики, чтобы принять решение об ограничении значений, которые войдут с финальный датасет для анализа.

# %%
def desc_stat(data, column):
    # descriptive statistics
    print(data[column].describe())
    data.boxplot(column=column, figsize=(3,7));
    plt.title('Descriptive Statistics')
    plt.show()
    data[column].hist(bins=30, range=(0, 110), figsize=(15, 5));

# %%
desc_stat(df_train, 'rougher.output.recovery')
# Out:
# count    12309.000000
# mean        83.293850
# std         13.157979
# min          0.000000
# 25%         80.335408
# 50%         85.417371
# 75%         90.013364
# max        100.000000
# Name: rougher.output.recovery, dtype: float64

# %% [markdown]
# **Выводы про целевой показатель _'rougher.output.recovery'_**
#
# - распределение несимметричное, отрицательно смещенное, так как среднее значение в 1-ом квартиле близко к mean и медиане (медиана и среднее близки по значениям, это хорошо), а стандартное отклонение более 10% среднего;
# - величина минимального и максимального значений целевого показателя 'final.output.recovery' также говорят о том, что имеются выбросы, которые можно ограничить для построения надежные предсказаний в модели;
# - в данных имеется хвост в 1-ом и 2-м квартилях.

# %%
desc_stat(df_train, 'final.output.recovery')
# Out:
# count    12309.000000
# mean        66.992047
# std          8.818194
# min          0.000000
# 25%         63.101966
# 50%         67.540745
# 75%         72.294152
# max        100.000000
# Name: final.output.recovery, dtype: float64

# %% [markdown]
# **Выводы про целевой показатель _'final.output.recovery'_**
# - распределение близко к нормальному, так как среднее mean и медиана близки по значениям, а стандартное отклоение небольшое;
# - из описатльных статистик видим, что max иm min value немного далеко от медианы и среднего, что говорит о небольшом отрицательном смещении целевого значения 'final.output.recovery' и наличии хвоста выбросов. Эти выбросы имеет смысл ограничить для получения чистых данных для обучения и чистого прогноза целевого показателя;
# - величина минимального и максимального значений целевого показателя 'final.output.recovery' также говорят о том, что имеются выбросы, которые можно ограничить для построения надежные предсказаний в модели.

# %% [markdown]
# ### Избавимся от выбросов в целевых показателях датасета, на котором будем проводить обучение

# %%
df_train = df_train.drop(df_train[(df_train['final.output.recovery'] < 56) | (df_train['final.output.recovery'] > 75) | (df_train['rougher.output.recovery'] < 70) | (df_train['rougher.output.recovery'] > 90)].index)

# %%
desc_stat(df_train, 'rougher.output.recovery')
# Out:
# count    7465.000000
# mean       82.863459
# std         4.659531
# min        70.005352
# 25%        79.839420
# 50%        83.440781
# 75%        86.615952
# max        89.995896
# Name: rougher.output.recovery, dtype: float64

# %%
desc_stat(df_train, 'final.output.recovery');
# Out:
# count    7465.000000
# mean       66.273279
# std         4.271910
# min        56.011452
# 25%        63.297993
# 50%        66.322744
# 75%        69.413674
# max        74.995458
# Name: final.output.recovery, dtype: float64

# %% [markdown]
# # Вывод
#
# Для обучения возьмем финальный датасет ***df_train***, в котором **7465 наблюдений** и нет выбросов. Основные описательные стастистики следующие:
# ```
#
# - 'rougher.output.recovery'
#
# mean       82.863459
# std         4.659531
# min        70.005352
# 25%        79.839420
# 50%        83.440781
# 75%        86.615952
# max        89.995896
#
# - 'final.output.recovery'
#
# mean       66.273279
# std         4.271910
# min        56.011452
# 25%        63.297993
# 50%        66.322744
# 75%        69.413674
# max        74.995458
#
# ```

# %% [markdown]
# ### Проверим выбросы и описательные статистики для тестового датасета

# %%
df_test.describe()
# Out:
#        primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# count                    5229.000000                       5229.000000
# mean                      175.842593                          8.714363
# std                        41.794368                          3.022147
# min                        17.886900                          0.113356
# 25%                       147.892868                          6.494356
# 50%                       178.326782                          8.066361
# 75%                       208.365965                         10.033999
# max                       265.983123                         20.046764
#
#        primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# count                      5229.000000                     5229.000000
# mean                          7.271546                        1.391267
# std                           0.605887                        0.640898
# min                           5.650000                        0.026293
# 25%                           6.900000                        0.912160
# 50%                           7.250000                        1.198638
# 75%                           7.600000                        1.801643
# max                          15.500000                        4.102454
#
#        primary_cleaner.state.floatbank8_a_air  \
# count                             5229.000000
# mean                              1539.976462
# std                                111.182711
# min                               1011.533202
# 25%                               1498.958074
# 50%                               1585.303338
# 75%                               1602.113128
# max                               1810.767191
#
#        primary_cleaner.state.floatbank8_a_level  \
# count                               5229.000000
# mean                                -497.767407
# std                                   18.120451
# min                                 -783.448551
# 25%                                 -500.357716
# 50%                                 -499.972297
# 75%                                 -499.575397
# max                                  -57.195404
#
#        primary_cleaner.state.floatbank8_b_air  \
# count                             5229.000000
# mean                              1546.004743
# std                                117.787666
# min                               1012.933963
# 25%                               1498.927702
# 50%                               1595.815696
# 75%                               1602.359135
# max                               1813.083671
#
#        primary_cleaner.state.floatbank8_b_level  \
# count                               5229.000000
# mean                                -499.929614
# std                                   29.847282
# min                                 -799.754942
# 25%                                 -500.700274
# 50%                                 -500.031165
# 75%                                 -499.303764
# max                                 -142.527229
#
#        primary_cleaner.state.floatbank8_c_air  \
# count                             5229.000000
# mean                              1529.120511
# std                                117.176468
# min                                212.035417
# 25%                               1474.759195
# 50%                               1549.773169
# 75%                               1601.221336
# max                               1715.053773
#
#        primary_cleaner.state.floatbank8_c_level  ...  \
# count                               5229.000000  ...
# mean                                -498.389260  ...
# std                                   20.273044  ...
# min                                 -786.260257  ...
# 25%                                 -501.013437  ...
# 50%                                 -500.021560  ...
# 75%                                 -499.005152  ...
# max                                 -150.937035  ...
#
#        secondary_cleaner.state.floatbank4_b_air  \
# count                              5.229000e+03
# mean                               1.375604e+01
# std                                3.406122e+00
# min                                2.489718e-17
# 25%                                1.203931e+01
# 50%                                1.496577e+01
# 75%                                1.596460e+01
# max                                3.126971e+01
#
#        secondary_cleaner.state.floatbank4_b_level  \
# count                                 5229.000000
# mean                                  -463.579964
# std                                     83.818061
# min                                   -799.868171
# 25%                                   -500.321863
# 50%                                   -499.573786
# 75%                                   -400.933793
# max                                    -53.213101
#
#        secondary_cleaner.state.floatbank5_a_air  \
# count                               5229.000000
# mean                                  12.834660
# std                                    3.017829
# min                                    6.032592
# 25%                                   10.916336
# 50%                                   12.959740
# 75%                                   15.166322
# max                                   25.258848
#
#        secondary_cleaner.state.floatbank5_a_level  \
# count                                 5229.000000
# mean                                  -501.122047
# std                                     16.374196
# min                                   -729.475816
# 25%                                   -500.724468
# 50%                                   -499.988941
# 75%                                   -499.287458
# max                                   -244.483566
#
#        secondary_cleaner.state.floatbank5_b_air  \
# count                               5229.000000
# mean                                   9.908257
# std                                    2.859360
# min                                    2.781642
# 25%                                    8.040758
# 50%                                   10.008542
# 75%                                   11.998487
# max                                   14.086866
#
#        secondary_cleaner.state.floatbank5_b_level  \
# count                                 5229.000000
# mean                                  -495.516030
# std                                     33.787701
# min                                   -614.076055
# 25%                                   -500.194501
# 50%                                   -499.990766
# 75%                                   -499.721253
# max                                   -137.740004
#
#        secondary_cleaner.state.floatbank6_a_air  \
# count                               5229.000000
# mean                                  17.353128
# std                                    4.518720
# min                                    0.127304
# 25%                                   13.999761
# 50%                                   16.016800
# 75%                                   21.022639
# max                                   26.705889
#
#        secondary_cleaner.state.floatbank6_a_level  final.output.recovery  \
# count                                 5229.000000           17509.000000
# mean                                  -501.638807              67.512404
# std                                     38.665655               8.716972
# min                                   -809.741464               0.000000
# 25%                                   -500.689156              63.799965
# 50%                                   -500.007063              68.342486
# 75%                                   -499.372917              72.666046
# max                                   -123.307487             100.000000
#
#        rougher.output.recovery
# count             17509.000000
# mean                 83.873696
# std                  13.090465
# min                   0.000000
# 25%                  81.495984
# 50%                  86.330798
# 75%                  89.916662
# max                 100.000000
#
# [8 rows x 54 columns]

# %%
df_test.hist(bins=30, figsize=(45, 40));

# %% [markdown]
# # Выводы
#
# - Путем очистки и объединения трех исходных датасетов получен финальный датасет **df_train**, который будет использоваться для формирования подвыборок и построения модели.
#
#
# - Путем очистки и объединения full_data, test_data получен финальный датасет **df_test**, который будет использоваться тестирования обученной модели.
#
# - Во всех данных и новых сформированных датасетах заполнены пропуски, удалены дубликаты, выбросы в целевых показателях очищены. Данные чистые и готовы к анализу.

# %% [markdown]
# <div class="alert alert-success">
# <h2> FYI <a class="tocSkip"> </h2>
#
# Видео по флотации руды:
#
# https://www.youtube.com/watch?v=BY9d1MC6qLs и
#
# https://www.youtube.com/watch?v=qYuGEjR8ZKw&t=13s

# %%
df_train.isna().sum()
# Out:
# date                                          0
# final.output.recovery                         0
# primary_cleaner.input.sulfate                 0
# primary_cleaner.input.depressant              0
# primary_cleaner.input.feed_size               0
# primary_cleaner.input.xanthate                0
# primary_cleaner.state.floatbank8_a_air        0
# primary_cleaner.state.floatbank8_a_level      0
# primary_cleaner.state.floatbank8_b_air        0
# primary_cleaner.state.floatbank8_b_level      0
# primary_cleaner.state.floatbank8_c_air        0
# primary_cleaner.state.floatbank8_c_level      0
# primary_cleaner.state.floatbank8_d_air        0
# primary_cleaner.state.floatbank8_d_level      0
# rougher.input.feed_ag                         0
# rougher.input.feed_pb                         0
# rougher.input.feed_rate                       0
# rougher.input.feed_size                       0
# rougher.input.feed_sol                        0
# rougher.input.feed_au                         0
# rougher.input.floatbank10_sulfate             0
# rougher.input.floatbank10_xanthate            0
# rougher.input.floatbank11_sulfate             0
# rougher.input.floatbank11_xanthate            0
# rougher.output.recovery                       0
# rougher.state.floatbank10_a_air               0
# rougher.state.floatbank10_a_level             0
# rougher.state.floatbank10_b_air               0
# rougher.state.floatbank10_b_level             0
# rougher.state.floatbank10_c_air               0
# rougher.state.floatbank10_c_level             0
# rougher.state.floatbank10_d_air               0
# rougher.state.floatbank10_d_level             0
# rougher.state.floatbank10_e_air               0
# rougher.state.floatbank10_e_level             0
# rougher.state.floatbank10_f_air               0
# rougher.state.floatbank10_f_level             0
# secondary_cleaner.state.floatbank2_a_air      0
# secondary_cleaner.state.floatbank2_a_level    0
# secondary_cleaner.state.floatbank2_b_air      0
# secondary_cleaner.state.floatbank2_b_level    0
# secondary_cleaner.state.floatbank3_a_air      0
# secondary_cleaner.state.floatbank3_a_level    0
# secondary_cleaner.state.floatbank3_b_air      0
# secondary_cleaner.state.floatbank3_b_level    0
# secondary_cleaner.state.floatbank4_a_air      0
# secondary_cleaner.state.floatbank4_a_level    0
# secondary_cleaner.state.floatbank4_b_air      0
# secondary_cleaner.state.floatbank4_b_level    0
# secondary_cleaner.state.floatbank5_a_air      0
# secondary_cleaner.state.floatbank5_a_level    0
# secondary_cleaner.state.floatbank5_b_air      0
# secondary_cleaner.state.floatbank5_b_level    0
# secondary_cleaner.state.floatbank6_a_air      0
# secondary_cleaner.state.floatbank6_a_level    0
# dtype: int64

# %%
df_test[['rougher.output.recovery', 'final.output.recovery']].isna().sum() / len(df_test)
# Out:
# rougher.output.recovery    0.004095
# final.output.recovery      0.004095
# dtype: float64

# %%
df_test = df_test.dropna(subset=['rougher.output.recovery', 'final.output.recovery'])
print(df_test[['rougher.output.recovery', 'final.output.recovery']].isna().sum() / len(df_test))
# Out:
# rougher.output.recovery    0.0
# final.output.recovery      0.0
# dtype: float64

# %% [markdown]
# ## Анализ данных

# %%
full_data.columns
# Out:
# Index(['date', 'final.output.concentrate_ag', 'final.output.concentrate_pb',
#        'final.output.concentrate_sol', 'final.output.concentrate_au',
#        'final.output.recovery', 'final.output.tail_ag', 'final.output.tail_pb',
#        'final.output.tail_sol', 'final.output.tail_au',
#        'primary_cleaner.input.sulfate', 'primary_cleaner.input.depressant',
#        'primary_cleaner.input.feed_size', 'primary_cleaner.input.xanthate',
#        'primary_cleaner.output.concentrate_ag',
#        'primary_cleaner.output.concentrate_pb',
#        'primary_cleaner.output.concentrate_sol',
#        'primary_cleaner.output.concentrate_au',
#        'primary_cleaner.output.tail_ag', 'primary_cleaner.output.tail_pb',
#        'primary_cleaner.output.tail_sol', 'primary_cleaner.output.tail_au',
#        'primary_cleaner.state.floatbank8_a_air',
#        'primary_cleaner.state.floatbank8_a_level',
#        'primary_cleaner.state.floatbank8_b_air',
#        'primary_cleaner.state.floatbank8_b_level',
#        'primary_cleaner.state.floatbank8_c_air',
#        'primary_cleaner.state.floatbank8_c_level',
#        'primary_cleaner.state.floatbank8_d_air',
#        'primary_cleaner.state.floatbank8_d_level',
#        'rougher.calculation.sulfate_to_au_concentrate',
#        'rougher.calculation.floatbank10_sulfate_to_au_feed',
#        'rougher.calculation.floatbank11_sulfate_to_au_feed',
#        'rougher.calculation.au_pb_ratio', 'rougher.input.feed_ag',
#        'rougher.input.feed_pb', 'rougher.input.feed_rate',
#        'rougher.input.feed_size', 'rougher.input.feed_sol',
#        'rougher.input.feed_au', 'rougher.input.floatbank10_sulfate',
#        'rougher.input.floatbank10_xanthate',
#        'rougher.input.floatbank11_sulfate',
#        'rougher.input.floatbank11_xanthate', 'rougher.output.concentrate_ag',
#        'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol',
#        'rougher.output.concentrate_au', 'rougher.output.recovery',
#        'rougher.output.tail_ag', 'rougher.output.tail_pb',
#        'rougher.output.tail_sol', 'rougher.output.tail_au',
#        'rougher.state.floatbank10_a_air', 'rougher.state.floatbank10_a_level',
#        'rougher.state.floatbank10_b_air', 'rougher.state.floatbank10_b_level',
#        'rougher.state.floatbank10_c_air', 'rougher.state.floatbank10_c_level',
#        'rougher.state.floatbank10_d_air', 'rougher.state.floatbank10_d_level',
#        'rougher.state.floatbank10_e_air', 'rougher.state.floatbank10_e_level',
#        'rougher.state.floatbank10_f_air', 'rougher.state.floatbank10_f_level',
#        'secondary_cleaner.output.tail_ag', 'secondary_cleaner.output.tail_pb',
#        'secondary_cleaner.output.tail_sol', 'secondary_cleaner.output.tail_au',
#        'secondary_cleaner.state.floatbank2_a_air',
#        'secondary_cleaner.state.floatbank2_a_level',
#        'secondary_cleaner.state.floatbank2_b_air',
#        'secondary_cleaner.state.floatbank2_b_level',
#        'secondary_cleaner.state.floatbank3_a_air',
#        'secondary_cleaner.state.floatbank3_a_level',
#        'secondary_cleaner.state.floatbank3_b_air',
#        'secondary_cleaner.state.floatbank3_b_level',
#        'secondary_cleaner.state.floatbank4_a_air',
#        'secondary_cleaner.state.floatbank4_a_level',
#        'secondary_cleaner.state.floatbank4_b_air',
#        'secondary_cleaner.state.floatbank4_b_level',
#        'secondary_cleaner.state.floatbank5_a_air',
#        'secondary_cleaner.state.floatbank5_a_level',
#        'secondary_cleaner.state.floatbank5_b_air',
#        'secondary_cleaner.state.floatbank5_b_level',
#        'secondary_cleaner.state.floatbank6_a_air',
#        'secondary_cleaner.state.floatbank6_a_level'],
#       dtype='object')

# %% [markdown]
# ### Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки.

# %% [markdown]
# ```
# Флотация
#
# 'rougher.input.feed_ag',
# 'rougher.input.feed_pb',
# 'rougher.input.feed_au',
# 'rougher.input.feed_sol',
#
# 'rougher.output.concentrate_ag',
# 'rougher.output.concentrate_au',
# 'rougher.output.concentrate_pb',
# 'rougher.output.concentrate_sol'
#
# Первичная очистка
#
# 'primary_cleaner.output.concentrate_ag',
# 'primary_cleaner.output.concentrate_au',
# 'primary_cleaner.output.concentrate_pb',
# 'primary_cleaner.output.concentrate_sol'
#
# ```

# %%
concentrate = {'ag':['rougher.output.concentrate_ag', 'primary_cleaner.output.concentrate_ag', 'final.output.concentrate_ag', 'rougher.input.feed_ag'],
               'au':['rougher.output.concentrate_au', 'primary_cleaner.output.concentrate_au', 'final.output.concentrate_au', 'rougher.input.feed_pb'],
               'pb':['rougher.output.concentrate_pb', 'primary_cleaner.output.concentrate_pb', 'final.output.concentrate_pb', 'rougher.input.feed_au'],
               'sol':['rougher.output.concentrate_sol', 'primary_cleaner.output.concentrate_sol', 'final.output.concentrate_sol', 'rougher.input.feed_sol']}
 
for i in concentrate:
    plt.figure(figsize=(16, 5))
    sns.boxplot(data = full_data[concentrate[i]])
    plt.title(f'Распределение значений доли материала {i} в концентрате на разных этапах')
    plt.show()

# %% [markdown]
# **Выводы о том, как меняется концентрация в зависимости от этапа**
#
# **AU - золото.** Концентрация золота закономерно возрастает от начального к конечному этапу - средние значения на финальном этапе находятся в районе 45 %, а это является самой большой величиной в концентрате. Изменение этих боксплотов закономерно показывает, что процесс идет успешно.
#
# **AG - серебро.** Концентрация серебра планомерно снижается в процессе обогащения, скорей всего происходит его вымывание из раствора на различных стадиях процесса. На финальном этапе среднее значение концентрации данного материала составляет около 5 %.
#
# **PB - свинец.** Концентрация свинца меняется незначительно в процессе обогащения, средние значения изменяются от 7.5 до 10 %. Предположительно, в процессе первичной очистки в раствор искусственно добавляется данный материал и далее не меняется.
#
# **SOL - прочие примеси.** Содержание прочих примесей особо велико после флотации, но при первичной очистке оно резко падает (средние значения уменьшаются в 3 раза), вторичная очистка не дает такого эффекта и содержание примесей в растворе почти не меняется.

# %% [markdown]
# ### Сравним распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.
#
# ```
# feed size — размер гранул сырья
# ```

# %% [markdown]
# В обучающем и тестовом датасете есть две колонки данных, которые отвечают за размер сырья на разных этапах очистки.
# ```
# 'rougher.input.feed_size'
# 'primary_cleaner.input.feed_size'
# ```
# Изучим эти данные с помощью описательных статистик и удалим выбросы, если они имеются.

# %%
fig = plt.figure(figsize=(17, 6))
sns.distplot(df_test['rougher.input.feed_size'])
sns.distplot(df_train['rougher.input.feed_size'])
plt.title('Распределение размера гранул на стадии флотации')
plt.xlabel('Размер гранул')
plt.ylabel('Частота')
plt.legend(labels=['Размер гранул в тестовой выборке','Размер гранул в обучающей выборке'])
plt.show()

# %% [markdown]
# - ***'rougher.input.feed_size'***

# %%
desc_stat(df_train, 'rougher.input.feed_size');
# Out:
# count    7465.000000
# mean       56.576992
# std        19.447995
# min         9.659576
# 25%        48.867399
# 50%        53.629477
# 75%        59.731149
# max       484.967466
# Name: rougher.input.feed_size, dtype: float64

# %%
desc_stat(df_test, 'rougher.input.feed_size');
# Out:
# count    5157.000000
# mean       55.294632
# std        16.218842
# min         0.046369
# 25%        43.897036
# 50%        50.617790
# 75%        61.962179
# max       368.035882
# Name: rougher.input.feed_size, dtype: float64

# %% [markdown]
# - ***'primary_cleaner.input.feed_size'***

# %%
fig = plt.figure(figsize=(17, 6))
sns.distplot(df_test['primary_cleaner.input.feed_size'])
sns.distplot(df_train['primary_cleaner.input.feed_size'])
plt.title('Распределение размера гранул на стадии первичной очистки')
plt.xlabel('Размер гранул')
plt.ylabel('Частота')
plt.legend(labels=['Размер гранул в тестовой выборке','Размер гранул в обучающей выборке'])
plt.show()

# %%
desc_stat(df_train, 'primary_cleaner.input.feed_size');
# Out:
# count    7465.000000
# mean        7.399475
# std         0.581974
# min         4.970000
# 25%         7.027500
# 50%         7.330000
# 75%         7.770000
# max        10.470000
# Name: primary_cleaner.input.feed_size, dtype: float64

# %%
desc_stat(df_test, 'primary_cleaner.input.feed_size');
# Out:
# count    5157.000000
# mean        7.281430
# std         0.599272
# min         5.650000
# 25%         6.900000
# 50%         7.250000
# 75%         7.610000
# max        15.500000
# Name: primary_cleaner.input.feed_size, dtype: float64

# %% [markdown]
# Видим, что в показателях размера сырья данные отличаются в обучающем и тестовом датасете. Чтобы получить валидные результаты, ограничим эти данные одинаково в обоих датасетах.

# %%
df_train_final = df_train.drop(df_train[(df_train['primary_cleaner.input.feed_size'] < 6.1) | (df_train['primary_cleaner.input.feed_size'] > 8.8) | (df_train['rougher.input.feed_size'] < 40) | (df_train['rougher.input.feed_size'] > 250)].index)

# %%
df_test_final = df_test.drop(df_test[(df_test['primary_cleaner.input.feed_size'] < 6.1) | (df_test['primary_cleaner.input.feed_size'] > 8.5) | (df_test['rougher.input.feed_size'] < 25) | (df_test['rougher.input.feed_size'] > 180)].index)

# %%
desc_stat(df_train_final, ['rougher.input.feed_size', 'primary_cleaner.input.feed_size']);
# Out:
#        rougher.input.feed_size  primary_cleaner.input.feed_size
# count              7117.000000                      7117.000000
# mean                 56.285017                         7.403957
# std                  12.597114                         0.531001
# min                  40.008954                         6.100000
# 25%                  49.208573                         7.040000
# 50%                  53.839394                         7.330000
# 75%                  59.791108                         7.760000
# max                 231.038835                         8.800000

# %%
desc_stat(df_test_final, ['rougher.input.feed_size', 'primary_cleaner.input.feed_size']);
# Out:
#        rougher.input.feed_size  primary_cleaner.input.feed_size
# count              4891.000000                      4891.000000
# mean                 55.016151                         7.269604
# std                  14.703913                         0.491244
# min                  25.891540                         6.110000
# 25%                  43.826292                         6.920000
# 50%                  50.075049                         7.250000
# 75%                  61.824189                         7.590000
# max                 154.568659                         8.500000

# %% [markdown]
# ### Различия распределения целевых признаков

# %% [markdown]
# **Deep Imbalanced Regression (DIR) can learn continuous targets from real-world imbalanced datasets and provide it to a deep learning model.**
#
# DIR is executed in two ways:
#
# - Label Distribution Smoothing
# - Feature Distribution Smoothing
#
# **DIR incorporates a kernel distribution function that leverages the similarity between adjacent target values and smoothens the distribution of either target or features.**

# %% [markdown]
# - 'primary_cleaner.input.feed_size'

# %%
target_primary_sqrt_train = np.sqrt(df_train_final['primary_cleaner.input.feed_size'])
target_primary_sqrt_train.skew()
# Out:
# 0.16909083123352964

# %%
target_primary_sqrt_test = np.sqrt(df_test_final['primary_cleaner.input.feed_size'])
target_primary_sqrt_test.skew()
# Out:
# 0.06275097474454833

# %% [markdown]
# - 'rougher.input.feed_size'

# %%
target_rougher_sqrt_train = np.sqrt(df_train_final['rougher.input.feed_size'])
target_rougher_sqrt_train.skew()
# Out:
# 3.0106225669951594

# %%
target_rougher_log_train = np.log(df_train_final['rougher.input.feed_size'])
target_rougher_log_train.skew()
# Out:
# 1.8202792201141818

# %%
type(target_rougher_log_train)
# Out:
# pandas.core.series.Series

# %%
target_rougher_log_train.hist(bins=45);

# %%
df_train_final['rougher.input.feed_size'].hist(bins=45);

# %%
target_rougher_sqrt_test = np.sqrt(df_test_final['rougher.input.feed_size'])
target_rougher_sqrt_test.skew()
# Out:
# 1.3456050942701798

# %% [markdown]
# **Вывод:** в идеале необходимо столбец ***df_train_final['rougher.input.feed_size']*** логарифмировать log() и перезаписать, чтобы убрать skewness.

# %% [markdown]
# # Вывод
# - В обучающем и тестовом наборах данных приведены к единым показателям величины размеров гранул на разных этапах очистки - 'rougher.input.feed_size' и 'primary_cleaner.input.feed_size'.
# - Получены 3936 наблюдений.
# - Обновлены и сформированы финальные датасеты для моделирования - df_train_final, df_test_final

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> To improve <a class="tocSkip"> </h2>
#
# <b>Тренировочную выборку разбивают на несколько частей и затем техниками upsampling/downsampling проводят подгонку к распределению тестовой выборки.</b>

# %% [markdown]
# <div class="alert alert-info">
#
# <b>https://datascience.stackexchange.com/questions/75239/data-imbalance-in-regression-tasks</b>
#
# https://neptune.ai/blog/how-to-deal-with-imbalanced-classification-and-regression-data
#
# http://dir.csail.mit.edu/
#
# https://towardsdatascience.com/top-3-methods-for-handling-skewed-data-1334e0debf45
# </div>
#
# <br/>

# %%
fig = plt.figure(figsize=(17, 6))
sns.distplot(df_test_final['rougher.input.feed_size'])
sns.distplot(df_train_final['rougher.input.feed_size'])
plt.title('Распределение размера гранул на стадии флотации')
plt.xlabel('Размер гранул')
plt.ylabel('Частота')
plt.legend(labels=['Размер гранул в тестовой выборке','Размер гранул в обучающей выборке'])
plt.show()

# %%
fig = plt.figure(figsize=(17, 6))
sns.distplot(df_test_final['primary_cleaner.input.feed_size'])
sns.distplot(df_train_final['primary_cleaner.input.feed_size'])
plt.title('Распределение размера гранул на стадии первичной очистки')
plt.xlabel('Размер гранул')
plt.ylabel('Частота')
plt.legend(labels=['Размер гранул в тестовой выборке','Размер гранул в обучающей выборке'])
plt.show()

# %% [markdown]
# **Вывод**
#
# - Распределение на этапе флотации ***'rougher.input.feed_size'*** схоже по форме как в обучающей, так и в тестовой выборках. Выбросы удалить удалось не полночтью, так как удаление выбросов приводило к смещению распределению и существенному отличию описательных статистик в обучающей и тестовой выборках.
#
# - Распределение после первичной очистки ***'primary_cleaner.input.feed_size'*** схоже по форме как в обучающей, так и в тестовой выборках. Выбросы удалось удалить полностью.

# %% [markdown]
# ### Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.

# %%
sum_concentrate = {'rougher_input':['rougher.input.feed_ag', 'rougher.input.feed_pb', 'rougher.input.feed_sol', 'rougher.input.feed_au'],
                'rougher_output':[x for x in full_data.columns if x.startswith('rougher.output.concentrate')],
               'primary_cleaner':[x for x in full_data.columns if x.startswith('primary_cleaner.output.concentrate')],
               'final':[x for x in full_data.columns if x.startswith('final.output.concentrate')]
                  }
 
for i in sum_concentrate:
 
    plt.figure(figsize=(17, 7))
    sns.distplot(np.sum(full_data[sum_concentrate[i]], axis = 1))
    plt.xlabel('Концетрация')
    plt.ylabel('Частота')
    plt.title(f'Суммарная концентрация всех веществ на стадии {i}')
    plt.show()

# %% [markdown]
# #### Изучим датасет с _обучающими_ данными, который планируем использовать для обучения модели.

# %%
df_train_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7117 entries, 0 to 14148
# Data columns (total 55 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        7117 non-null   object
#  1   final.output.recovery                       7117 non-null   float64
#  2   primary_cleaner.input.sulfate               7117 non-null   float64
#  3   primary_cleaner.input.depressant            7117 non-null   float64
#  4   primary_cleaner.input.feed_size             7117 non-null   float64
#  5   primary_cleaner.input.xanthate              7117 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_air      7117 non-null   float64
#  7   primary_cleaner.state.floatbank8_a_level    7117 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_air      7117 non-null   float64
#  9   primary_cleaner.state.floatbank8_b_level    7117 non-null   float64
#  10  primary_cleaner.state.floatbank8_c_air      7117 non-null   float64
#  11  primary_cleaner.state.floatbank8_c_level    7117 non-null   float64
#  12  primary_cleaner.state.floatbank8_d_air      7117 non-null   float64
#  13  primary_cleaner.state.floatbank8_d_level    7117 non-null   float64
#  14  rougher.input.feed_ag                       7117 non-null   float64
#  15  rougher.input.feed_pb                       7117 non-null   float64
#  16  rougher.input.feed_rate                     7117 non-null   float64
#  17  rougher.input.feed_size                     7117 non-null   float64
#  18  rougher.input.feed_sol                      7117 non-null   float64
#  19  rougher.input.feed_au                       7117 non-null   float64
#  20  rougher.input.floatbank10_sulfate           7117 non-null   float64
#  21  rougher.input.floatbank10_xanthate          7117 non-null   float64
#  22  rougher.input.floatbank11_sulfate           7117 non-null   float64
#  23  rougher.input.floatbank11_xanthate          7117 non-null   float64
#  24  rougher.output.recovery                     7117 non-null   float64
#  25  rougher.state.floatbank10_a_air             7117 non-null   float64
#  26  rougher.state.floatbank10_a_level           7117 non-null   float64
#  27  rougher.state.floatbank10_b_air             7117 non-null   float64
#  28  rougher.state.floatbank10_b_level           7117 non-null   float64
#  29  rougher.state.floatbank10_c_air             7117 non-null   float64
#  30  rougher.state.floatbank10_c_level           7117 non-null   float64
#  31  rougher.state.floatbank10_d_air             7117 non-null   float64
#  32  rougher.state.floatbank10_d_level           7117 non-null   float64
#  33  rougher.state.floatbank10_e_air             7117 non-null   float64
#  34  rougher.state.floatbank10_e_level           7117 non-null   float64
#  35  rougher.state.floatbank10_f_air             7117 non-null   float64
#  36  rougher.state.floatbank10_f_level           7117 non-null   float64
#  37  secondary_cleaner.state.floatbank2_a_air    7117 non-null   float64
#  38  secondary_cleaner.state.floatbank2_a_level  7117 non-null   float64
#  39  secondary_cleaner.state.floatbank2_b_air    7117 non-null   float64
#  40  secondary_cleaner.state.floatbank2_b_level  7117 non-null   float64
#  41  secondary_cleaner.state.floatbank3_a_air    7117 non-null   float64
#  42  secondary_cleaner.state.floatbank3_a_level  7117 non-null   float64
#  43  secondary_cleaner.state.floatbank3_b_air    7117 non-null   float64
#  44  secondary_cleaner.state.floatbank3_b_level  7117 non-null   float64
#  45  secondary_cleaner.state.floatbank4_a_air    7117 non-null   float64
#  46  secondary_cleaner.state.floatbank4_a_level  7117 non-null   float64
#  47  secondary_cleaner.state.floatbank4_b_air    7117 non-null   float64
#  48  secondary_cleaner.state.floatbank4_b_level  7117 non-null   float64
#  49  secondary_cleaner.state.floatbank5_a_air    7117 non-null   float64
#  50  secondary_cleaner.state.floatbank5_a_level  7117 non-null   float64
#  51  secondary_cleaner.state.floatbank5_b_air    7117 non-null   float64
#  52  secondary_cleaner.state.floatbank5_b_level  7117 non-null   float64
#  53  secondary_cleaner.state.floatbank6_a_air    7117 non-null   float64
#  54  secondary_cleaner.state.floatbank6_a_level  7117 non-null   float64
# dtypes: float64(54), object(1)
# memory usage: 3.0+ MB

# %% [markdown]
# Датасет ***df_train_final*** содержит следующие столбцы:
#
# ```
# 'rougher.input.feed_ag',
# 'rougher.input.feed_pb',
# 'rougher.input.feed_sol',
# 'rougher.input.feed_au'
# ```
#
# **Удалим выбросы.**

# %%
desc_stat(df_train_final, 
          ['rougher.input.feed_ag',
           'rougher.input.feed_pb',
           'rougher.input.feed_sol', 
           'rougher.input.feed_au']);
# Out:
#        rougher.input.feed_ag  rougher.input.feed_pb  rougher.input.feed_sol  \
# count            7117.000000            7117.000000             7117.000000
# mean                8.215354               3.365125               36.607467
# std                 1.506404               0.897025                4.170933
# min                 2.215688               0.157686                7.991683
# 25%                 7.091282               2.763599               34.237769
# 50%                 7.869240               3.335724               36.967853
# 75%                 9.095354               3.969795               39.219495
# max                13.635650               6.337645               48.363177
#
#        rougher.input.feed_au
# count            7117.000000
# mean                7.674659
# std                 1.536550
# min                 2.121669
# 25%                 6.635975
# 50%                 7.464092
# 75%                 8.521638
# max                12.644983

# %%
df_train_final = df_train_final.drop(df_train_final[
    (df_train_final['rougher.input.feed_ag'] < 5) | (df_train_final['rougher.input.feed_ag'] > 11) 
    |(df_train_final['rougher.input.feed_pb'] < 1.5) | (df_train_final['rougher.input.feed_pb'] > 5) 
    |(df_train_final['rougher.input.feed_sol'] < 30) | (df_train_final['rougher.input.feed_sol'] > 45)
    |(df_train_final['rougher.input.feed_au'] < 7) | (df_train_final['rougher.input.feed_au'] > 10)
].index)

# %% [markdown]
# <div class="alert alert-success">
# <h2> FYI<a class="tocSkip"> </h2>
#
# <b>Cуммарную концентрацию всех веществ на разных стадиях исследовали и нашли аномалии.</b>
#
# Ведь отдельно по каждому веществу они могут быть (не всегда же есть крупицы золота в руде), а вот суммарно - вряд ли (в руде хоть какие-то элементы, но будут). А если мы имеем ноль, значит большая вероятность неточности в измерениях.
#
# Выборку нужно очистить от таких аномалий.

# %%
desc_stat(df_train_final, 
          ['rougher.input.feed_ag',
           'rougher.input.feed_pb',
           'rougher.input.feed_sol', 
           'rougher.input.feed_au']);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/f0/6n5cj1pd2td3sgkgfsl766lr0000gn/T/ipykernel_90315/3580512864.py in <module>
# ----> 1 desc_stat(df_train_final,
#       2           ['rougher.input.feed_ag',
#       3            'rougher.input.feed_pb',
#       4            'rougher.input.feed_sol',
#       5            'rougher.input.feed_au']);
#
# NameError: name 'desc_stat' is not defined

# %% [markdown]
# **Выбросы в обучающем датасете удалены. Датасет df_train_final готов для моделирования.**

# %% [markdown]
# #### Изучим _тестовый_ датасет, который планируем использовать для тестирования модели.

# %%
len(df_test_final.columns)
# Out:
# 55

# %% [markdown]
# Из выдачи выше видим, что в тестовом датасете отсутствуют столбцы с данными о концентрации веществ, которые есть в полных данных ***full_data***. Нам эти столбцы важны для моделирования и тестирования модели, поэтому дополним тестовый датасет следующими столбцами:
#
# ```
# из full_data:
#
# 'final.output.concentrate_ag',
# 'final.output.concentrate_pb ',
# 'final.output.concentrate_sol ',
# 'final.output.concentrate_au',
#
# 'rougher.output.concentrate_ag',
# 'rougher.output.concentrate_pb ',
# 'rougher.output.concentrate_sol',
# 'rougher.output.concentrate_au'
# ```

# %%
full_data.columns
# Out:
# Index(['date', 'final.output.concentrate_ag', 'final.output.concentrate_pb',
#        'final.output.concentrate_sol', 'final.output.concentrate_au',
#        'final.output.recovery', 'final.output.tail_ag', 'final.output.tail_pb',
#        'final.output.tail_sol', 'final.output.tail_au',
#        'primary_cleaner.input.sulfate', 'primary_cleaner.input.depressant',
#        'primary_cleaner.input.feed_size', 'primary_cleaner.input.xanthate',
#        'primary_cleaner.output.concentrate_ag',
#        'primary_cleaner.output.concentrate_pb',
#        'primary_cleaner.output.concentrate_sol',
#        'primary_cleaner.output.concentrate_au',
#        'primary_cleaner.output.tail_ag', 'primary_cleaner.output.tail_pb',
#        'primary_cleaner.output.tail_sol', 'primary_cleaner.output.tail_au',
#        'primary_cleaner.state.floatbank8_a_air',
#        'primary_cleaner.state.floatbank8_a_level',
#        'primary_cleaner.state.floatbank8_b_air',
#        'primary_cleaner.state.floatbank8_b_level',
#        'primary_cleaner.state.floatbank8_c_air',
#        'primary_cleaner.state.floatbank8_c_level',
#        'primary_cleaner.state.floatbank8_d_air',
#        'primary_cleaner.state.floatbank8_d_level',
#        'rougher.calculation.sulfate_to_au_concentrate',
#        'rougher.calculation.floatbank10_sulfate_to_au_feed',
#        'rougher.calculation.floatbank11_sulfate_to_au_feed',
#        'rougher.calculation.au_pb_ratio', 'rougher.input.feed_ag',
#        'rougher.input.feed_pb', 'rougher.input.feed_rate',
#        'rougher.input.feed_size', 'rougher.input.feed_sol',
#        'rougher.input.feed_au', 'rougher.input.floatbank10_sulfate',
#        'rougher.input.floatbank10_xanthate',
#        'rougher.input.floatbank11_sulfate',
#        'rougher.input.floatbank11_xanthate', 'rougher.output.concentrate_ag',
#        'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol',
#        'rougher.output.concentrate_au', 'rougher.output.recovery',
#        'rougher.output.tail_ag', 'rougher.output.tail_pb',
#        'rougher.output.tail_sol', 'rougher.output.tail_au',
#        'rougher.state.floatbank10_a_air', 'rougher.state.floatbank10_a_level',
#        'rougher.state.floatbank10_b_air', 'rougher.state.floatbank10_b_level',
#        'rougher.state.floatbank10_c_air', 'rougher.state.floatbank10_c_level',
#        'rougher.state.floatbank10_d_air', 'rougher.state.floatbank10_d_level',
#        'rougher.state.floatbank10_e_air', 'rougher.state.floatbank10_e_level',
#        'rougher.state.floatbank10_f_air', 'rougher.state.floatbank10_f_level',
#        'secondary_cleaner.output.tail_ag', 'secondary_cleaner.output.tail_pb',
#        'secondary_cleaner.output.tail_sol', 'secondary_cleaner.output.tail_au',
#        'secondary_cleaner.state.floatbank2_a_air',
#        'secondary_cleaner.state.floatbank2_a_level',
#        'secondary_cleaner.state.floatbank2_b_air',
#        'secondary_cleaner.state.floatbank2_b_level',
#        'secondary_cleaner.state.floatbank3_a_air',
#        'secondary_cleaner.state.floatbank3_a_level',
#        'secondary_cleaner.state.floatbank3_b_air',
#        'secondary_cleaner.state.floatbank3_b_level',
#        'secondary_cleaner.state.floatbank4_a_air',
#        'secondary_cleaner.state.floatbank4_a_level',
#        'secondary_cleaner.state.floatbank4_b_air',
#        'secondary_cleaner.state.floatbank4_b_level',
#        'secondary_cleaner.state.floatbank5_a_air',
#        'secondary_cleaner.state.floatbank5_a_level',
#        'secondary_cleaner.state.floatbank5_b_air',
#        'secondary_cleaner.state.floatbank5_b_level',
#        'secondary_cleaner.state.floatbank6_a_air',
#        'secondary_cleaner.state.floatbank6_a_level'],
#       dtype='object')

# %%
df_test_final.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17243 entries, 0 to 17580
# Data columns (total 55 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        17243 non-null  object
#  1   primary_cleaner.input.sulfate               4891 non-null   float64
#  2   primary_cleaner.input.depressant            4891 non-null   float64
#  3   primary_cleaner.input.feed_size             4891 non-null   float64
#  4   primary_cleaner.input.xanthate              4891 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      4891 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    4891 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      4891 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    4891 non-null   float64
#  9   primary_cleaner.state.floatbank8_c_air      4891 non-null   float64
#  10  primary_cleaner.state.floatbank8_c_level    4891 non-null   float64
#  11  primary_cleaner.state.floatbank8_d_air      4891 non-null   float64
#  12  primary_cleaner.state.floatbank8_d_level    4891 non-null   float64
#  13  rougher.input.feed_ag                       4891 non-null   float64
#  14  rougher.input.feed_pb                       4891 non-null   float64
#  15  rougher.input.feed_rate                     4891 non-null   float64
#  16  rougher.input.feed_size                     4891 non-null   float64
#  17  rougher.input.feed_sol                      4891 non-null   float64
#  18  rougher.input.feed_au                       4891 non-null   float64
#  19  rougher.input.floatbank10_sulfate           4891 non-null   float64
#  20  rougher.input.floatbank10_xanthate          4891 non-null   float64
#  21  rougher.input.floatbank11_sulfate           4891 non-null   float64
#  22  rougher.input.floatbank11_xanthate          4891 non-null   float64
#  23  rougher.state.floatbank10_a_air             4891 non-null   float64
#  24  rougher.state.floatbank10_a_level           4891 non-null   float64
#  25  rougher.state.floatbank10_b_air             4891 non-null   float64
#  26  rougher.state.floatbank10_b_level           4891 non-null   float64
#  27  rougher.state.floatbank10_c_air             4891 non-null   float64
#  28  rougher.state.floatbank10_c_level           4891 non-null   float64
#  29  rougher.state.floatbank10_d_air             4891 non-null   float64
#  30  rougher.state.floatbank10_d_level           4891 non-null   float64
#  31  rougher.state.floatbank10_e_air             4891 non-null   float64
#  32  rougher.state.floatbank10_e_level           4891 non-null   float64
#  33  rougher.state.floatbank10_f_air             4891 non-null   float64
#  34  rougher.state.floatbank10_f_level           4891 non-null   float64
#  35  secondary_cleaner.state.floatbank2_a_air    4891 non-null   float64
#  36  secondary_cleaner.state.floatbank2_a_level  4891 non-null   float64
#  37  secondary_cleaner.state.floatbank2_b_air    4891 non-null   float64
#  38  secondary_cleaner.state.floatbank2_b_level  4891 non-null   float64
#  39  secondary_cleaner.state.floatbank3_a_air    4891 non-null   float64
#  40  secondary_cleaner.state.floatbank3_a_level  4891 non-null   float64
#  41  secondary_cleaner.state.floatbank3_b_air    4891 non-null   float64
#  42  secondary_cleaner.state.floatbank3_b_level  4891 non-null   float64
#  43  secondary_cleaner.state.floatbank4_a_air    4891 non-null   float64
#  44  secondary_cleaner.state.floatbank4_a_level  4891 non-null   float64
#  45  secondary_cleaner.state.floatbank4_b_air    4891 non-null   float64
#  46  secondary_cleaner.state.floatbank4_b_level  4891 non-null   float64
#  47  secondary_cleaner.state.floatbank5_a_air    4891 non-null   float64
#  48  secondary_cleaner.state.floatbank5_a_level  4891 non-null   float64
#  49  secondary_cleaner.state.floatbank5_b_air    4891 non-null   float64
#  50  secondary_cleaner.state.floatbank5_b_level  4891 non-null   float64
#  51  secondary_cleaner.state.floatbank6_a_air    4891 non-null   float64
#  52  secondary_cleaner.state.floatbank6_a_level  4891 non-null   float64
#  53  final.output.recovery                       17243 non-null  float64
#  54  rougher.output.recovery                     17243 non-null  float64
# dtypes: float64(54), object(1)
# memory usage: 7.4+ MB

# %% [markdown]
# Обучающие и тестовые данные дополнены параметрами концентрации для разных металлов на разных стадиях.

# %%
sum_concentrate = {'rougher_input':['rougher.input.feed_ag', 'rougher.input.feed_pb', 'rougher.input.feed_sol', 'rougher.input.feed_au'],
                'rougher_output':[x for x in df_train_final.columns if x.startswith('rougher.output.concentrate')],
               'primary_cleaner':[x for x in df_train_final.columns if x.startswith('primary_cleaner.output.concentrate')],
               'final':[x for x in df_train_final.columns if x.startswith('final.output.concentrate')]
                  }
 
for i in sum_concentrate:
 
    plt.figure(figsize=(17, 7))
    sns.distplot(np.sum(df_train_final[sum_concentrate[i]], axis = 1))
    plt.xlabel('Концетрация')
    plt.ylabel('Частота')
    plt.title(f'Суммарная концентрация всех веществ на стадии {i} в обучающих данных')
    plt.show()

# %%
sum_concentrate = {'rougher_input':['rougher.input.feed_ag', 'rougher.input.feed_pb', 'rougher.input.feed_sol', 'rougher.input.feed_au'],
                'rougher_output':[x for x in df_test_final.columns if x.startswith('rougher.output.concentrate')],
               'primary_cleaner':[x for x in df_test_final.columns if x.startswith('primary_cleaner.output.concentrate')],
               'final':[x for x in df_test_final.columns if x.startswith('final.output.concentrate')]
                  }
 
for i in sum_concentrate:
 
    plt.figure(figsize=(17, 7))
    sns.distplot(np.sum(df_test_final[sum_concentrate[i]], axis = 1))
    plt.xlabel('Концетрация')
    plt.ylabel('Частота')
    plt.title(f'Суммарная концентрация всех веществ на стадии {i} в тестовых данных')
    plt.show()

# %% [markdown]
# # Вывод
#
# - Концентрация основного элемента (золота) закономерно возрастает в процессе обогащения. Концентрация серебра и прочих примесей падает по ходу технологического процесса. Концентрация свинца практически не меняется, что обусловлено необходимостью дальнейшей более кропотливой обработки финального продукта.
#
# - Распределения размеров гранул сырья на обучающей и тестовых выборках не имеют значительных отличий. Перед первичной очисткой размер гранул снижается практически в 10 раз, что говорит о их расщеплении во время флотации.
#
# - Суммарная концентрация веществ увеличивается с течением процесса обогащения (колокол как бы сдвигается вправо по шкале), что закономерно, т.к. при обработке вымываются лишние примеси и подсадочные реагенты.
#
# - На стадии первичной очистки были выявлены выбросы, когда суммарная концентрация равнялась нулю. Скорей всего, процесс обогащения был остановлен в это время, поэтому такие данные участвовать в модели не должны и были удалены из всех выборок.

# %%
df_train_final.isna().sum()
# Out:
# date                                          0
# final.output.recovery                         0
# primary_cleaner.input.sulfate                 0
# primary_cleaner.input.depressant              0
# primary_cleaner.input.feed_size               0
# primary_cleaner.input.xanthate                0
# primary_cleaner.state.floatbank8_a_air        0
# primary_cleaner.state.floatbank8_a_level      0
# primary_cleaner.state.floatbank8_b_air        0
# primary_cleaner.state.floatbank8_b_level      0
# primary_cleaner.state.floatbank8_c_air        0
# primary_cleaner.state.floatbank8_c_level      0
# primary_cleaner.state.floatbank8_d_air        0
# primary_cleaner.state.floatbank8_d_level      0
# rougher.input.feed_ag                         0
# rougher.input.feed_pb                         0
# rougher.input.feed_rate                       0
# rougher.input.feed_size                       0
# rougher.input.feed_sol                        0
# rougher.input.feed_au                         0
# rougher.input.floatbank10_sulfate             0
# rougher.input.floatbank10_xanthate            0
# rougher.input.floatbank11_sulfate             0
# rougher.input.floatbank11_xanthate            0
# rougher.output.recovery                       0
# rougher.state.floatbank10_a_air               0
# rougher.state.floatbank10_a_level             0
# rougher.state.floatbank10_b_air               0
# rougher.state.floatbank10_b_level             0
# rougher.state.floatbank10_c_air               0
# rougher.state.floatbank10_c_level             0
# rougher.state.floatbank10_d_air               0
# rougher.state.floatbank10_d_level             0
# rougher.state.floatbank10_e_air               0
# rougher.state.floatbank10_e_level             0
# rougher.state.floatbank10_f_air               0
# rougher.state.floatbank10_f_level             0
# secondary_cleaner.state.floatbank2_a_air      0
# secondary_cleaner.state.floatbank2_a_level    0
# secondary_cleaner.state.floatbank2_b_air      0
# secondary_cleaner.state.floatbank2_b_level    0
# secondary_cleaner.state.floatbank3_a_air      0
# secondary_cleaner.state.floatbank3_a_level    0
# secondary_cleaner.state.floatbank3_b_air      0
# secondary_cleaner.state.floatbank3_b_level    0
# secondary_cleaner.state.floatbank4_a_air      0
# secondary_cleaner.state.floatbank4_a_level    0
# secondary_cleaner.state.floatbank4_b_air      0
# secondary_cleaner.state.floatbank4_b_level    0
# secondary_cleaner.state.floatbank5_a_air      0
# secondary_cleaner.state.floatbank5_a_level    0
# secondary_cleaner.state.floatbank5_b_air      0
# secondary_cleaner.state.floatbank5_b_level    0
# secondary_cleaner.state.floatbank6_a_air      0
# secondary_cleaner.state.floatbank6_a_level    0
# dtype: int64

# %%
df_test_final.isna().sum()
# Out:
# date                                              0
# primary_cleaner.input.sulfate                 12352
# primary_cleaner.input.depressant              12352
# primary_cleaner.input.feed_size               12352
# primary_cleaner.input.xanthate                12352
# primary_cleaner.state.floatbank8_a_air        12352
# primary_cleaner.state.floatbank8_a_level      12352
# primary_cleaner.state.floatbank8_b_air        12352
# primary_cleaner.state.floatbank8_b_level      12352
# primary_cleaner.state.floatbank8_c_air        12352
# primary_cleaner.state.floatbank8_c_level      12352
# primary_cleaner.state.floatbank8_d_air        12352
# primary_cleaner.state.floatbank8_d_level      12352
# rougher.input.feed_ag                         12352
# rougher.input.feed_pb                         12352
# rougher.input.feed_rate                       12352
# rougher.input.feed_size                       12352
# rougher.input.feed_sol                        12352
# rougher.input.feed_au                         12352
# rougher.input.floatbank10_sulfate             12352
# rougher.input.floatbank10_xanthate            12352
# rougher.input.floatbank11_sulfate             12352
# rougher.input.floatbank11_xanthate            12352
# rougher.state.floatbank10_a_air               12352
# rougher.state.floatbank10_a_level             12352
# rougher.state.floatbank10_b_air               12352
# rougher.state.floatbank10_b_level             12352
# rougher.state.floatbank10_c_air               12352
# rougher.state.floatbank10_c_level             12352
# rougher.state.floatbank10_d_air               12352
# rougher.state.floatbank10_d_level             12352
# rougher.state.floatbank10_e_air               12352
# rougher.state.floatbank10_e_level             12352
# rougher.state.floatbank10_f_air               12352
# rougher.state.floatbank10_f_level             12352
# secondary_cleaner.state.floatbank2_a_air      12352
# secondary_cleaner.state.floatbank2_a_level    12352
# secondary_cleaner.state.floatbank2_b_air      12352
# secondary_cleaner.state.floatbank2_b_level    12352
# secondary_cleaner.state.floatbank3_a_air      12352
# secondary_cleaner.state.floatbank3_a_level    12352
# secondary_cleaner.state.floatbank3_b_air      12352
# secondary_cleaner.state.floatbank3_b_level    12352
# secondary_cleaner.state.floatbank4_a_air      12352
# secondary_cleaner.state.floatbank4_a_level    12352
# secondary_cleaner.state.floatbank4_b_air      12352
# secondary_cleaner.state.floatbank4_b_level    12352
# secondary_cleaner.state.floatbank5_a_air      12352
# secondary_cleaner.state.floatbank5_a_level    12352
# secondary_cleaner.state.floatbank5_b_air      12352
# secondary_cleaner.state.floatbank5_b_level    12352
# secondary_cleaner.state.floatbank6_a_air      12352
# secondary_cleaner.state.floatbank6_a_level    12352
# final.output.recovery                             0
# rougher.output.recovery                           0
# dtype: int64

# %%
df_test_final = df_test_final.dropna()

# %%
df_test_final.isna().sum()
# Out:
# date                                          0
# primary_cleaner.input.sulfate                 0
# primary_cleaner.input.depressant              0
# primary_cleaner.input.feed_size               0
# primary_cleaner.input.xanthate                0
# primary_cleaner.state.floatbank8_a_air        0
# primary_cleaner.state.floatbank8_a_level      0
# primary_cleaner.state.floatbank8_b_air        0
# primary_cleaner.state.floatbank8_b_level      0
# primary_cleaner.state.floatbank8_c_air        0
# primary_cleaner.state.floatbank8_c_level      0
# primary_cleaner.state.floatbank8_d_air        0
# primary_cleaner.state.floatbank8_d_level      0
# rougher.input.feed_ag                         0
# rougher.input.feed_pb                         0
# rougher.input.feed_rate                       0
# rougher.input.feed_size                       0
# rougher.input.feed_sol                        0
# rougher.input.feed_au                         0
# rougher.input.floatbank10_sulfate             0
# rougher.input.floatbank10_xanthate            0
# rougher.input.floatbank11_sulfate             0
# rougher.input.floatbank11_xanthate            0
# rougher.state.floatbank10_a_air               0
# rougher.state.floatbank10_a_level             0
# rougher.state.floatbank10_b_air               0
# rougher.state.floatbank10_b_level             0
# rougher.state.floatbank10_c_air               0
# rougher.state.floatbank10_c_level             0
# rougher.state.floatbank10_d_air               0
# rougher.state.floatbank10_d_level             0
# rougher.state.floatbank10_e_air               0
# rougher.state.floatbank10_e_level             0
# rougher.state.floatbank10_f_air               0
# rougher.state.floatbank10_f_level             0
# secondary_cleaner.state.floatbank2_a_air      0
# secondary_cleaner.state.floatbank2_a_level    0
# secondary_cleaner.state.floatbank2_b_air      0
# secondary_cleaner.state.floatbank2_b_level    0
# secondary_cleaner.state.floatbank3_a_air      0
# secondary_cleaner.state.floatbank3_a_level    0
# secondary_cleaner.state.floatbank3_b_air      0
# secondary_cleaner.state.floatbank3_b_level    0
# secondary_cleaner.state.floatbank4_a_air      0
# secondary_cleaner.state.floatbank4_a_level    0
# secondary_cleaner.state.floatbank4_b_air      0
# secondary_cleaner.state.floatbank4_b_level    0
# secondary_cleaner.state.floatbank5_a_air      0
# secondary_cleaner.state.floatbank5_a_level    0
# secondary_cleaner.state.floatbank5_b_air      0
# secondary_cleaner.state.floatbank5_b_level    0
# secondary_cleaner.state.floatbank6_a_air      0
# secondary_cleaner.state.floatbank6_a_level    0
# final.output.recovery                         0
# rougher.output.recovery                       0
# dtype: int64

# %% [markdown]
# ## Модель

# %% [markdown]
# **Метрика качества**
#
# Для решения задачи введём метрику качества — **sMAPE (англ. Symmetric Mean Absolute Percentage Error, "симметричное среднее абсолютное процентное отклонение").**
#
# Она похожа на MAE, но выражается не в абсолютных величинах, а в относительных. Почему симметричная? Она одинаково учитывает масштаб и целевого признака, и предсказания.
#
# **Метрика sMAPE вычисляется так:**
#
#  ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Нужно спрогнозировать сразу две величины:
#
# - 1.	эффективность обогащения чернового концентрата ***rougher.output.recovery***;
#
# - 2.	эффективность обогащения финального концентрата ***final.output.recovery***.
#
#  ![image.png](attachment:image.png)

# %% [markdown]
# ### Напишем функцию для вычисления итоговой sMAPE.

# %%
def smape(target, predictions):
    numerator = abs(predictions - target)
    denominator = (abs(target) + abs(predictions)) / 2
    total = (numerator / denominator).sum()
    smape = (1 / len(target)) * total * 100
    return smape

# %% [markdown]
# ### Напишем функцию для проверки модели кросс-валидацией

# %%
from sklearn.metrics import make_scorer

# %%
def cross_valid(model, features, target):
    scores = cross_val_score(model, features, target, cv=2,n_jobs=-1, 
                             scoring=make_scorer(smape, greater_is_better=True))
    smape_res = np.mean(scores)
    return smape_res

# %% [markdown]
# ### Создадим функцию для автоматического вывода smape каждого этапа и финальной sMAPE

# %%
def model_smape(model):
    smape_rougher = cross_valid(model, train_features_rougher, train_target_rougher)
    smape_final = cross_valid(model, train_features_final, train_target_final)
    smape_end = 0.25 * smape_rougher + 0.75 * smape_final
    print('Средняя оценка качества по кросс-валидации на этапе флотации составила', smape_rougher)
    print('Средняя оценка качества по кросс-валидации на финальном этапе составила', smape_final)
    print('Конечная оценка качества по кросс-валидации составила', smape_end)

# %% [markdown]
# ### Обучим разные модели и оценим их качество кросс-валидацией. Выберем лучшую модель и проверим её на тестовой выборке.

# %%
len(df_train_final.columns)
# Out:
# 55

# %%
len(df_test_final.columns)
# Out:
# 55

# %% [markdown]
# #### Подготовим обучающие выборки - признаки и целевые признаки - для этапа _флотации_ и _финального_ этапа очистки

# %%
# подготовим список признаков для этапа флотации
features_rougher = []
for column in row_test_columns:
    if "rougher" in column:
        features_rougher.append(column)

train_features_rougher = df_train_final[features_rougher]
train_target_rougher = df_train_final['rougher.output.recovery']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_180/3641907559.py in <module>
#       1 # подготовим список признаков для этапа флотации
#       2 features_rougher = []
# ----> 3 for column in row_test_columns:
#       4     if "rougher" in column:
#       5         features_rougher.append(column)
#
# NameError: name 'row_test_columns' is not defined

# %%
# подготовим признаки для финального этапа
train_features_final = df_train_final[df_test_final.columns].drop(['rougher.output.recovery','final.output.recovery'], axis=1)
train_target_final = df_train_final['final.output.recovery']

# %%
# подготовим тестовые выборки
test_features_rougher = df_test_final[features_rougher]
test_target_rougher = df_test_final['rougher.output.recovery']
test_features_final = df_test_final.drop(['rougher.output.recovery','final.output.recovery'], axis=1)
test_target_final = df_test_final['final.output.recovery']

# %% [markdown]
# Итого, у нас имеются обучающая и тестовая выборки для каждого этапа очистки - флотации и первичной стадии; всего **8 готовых датасетов**.
#
# **Обучающие выборки:**
#
# - *флотация*: ***train_features_rougher, train_target_rougher***
#
# - *финальный этап очиски*: ***train_features_final, train_target_final***
#
# **Тестовые выборки:**
#
# - *флотация*: ***test_features_rougher, test_target_rougher***
# - *финальный этап очиски*: ***test_features_final, test_target_final***

# %% [markdown]
# ### Строим модели для данных при ***флотации***

# %% [markdown]
# #### Проведем масштабирование признаков на этапе флотации

# %%
len(train_features_rougher.columns)

# %%
len(train_features_final.columns)

# %%
len(test_features_rougher.columns)

# %%
len(test_features_final.columns)

# %%
# обучающие данные
# проведем масштабирование признаков этапа флотации
scaler_rougher = StandardScaler()
scaler_rougher.fit(train_features_rougher)

train_col_rougher = train_features_rougher.columns
test_col_rougher = test_features_rougher.columns

# Чтобы не было утечки в тестовую выборку, StandardScaler() необходимо обучать на тренировочной выборке, 
# а применять ко всем выборкам.

train_features_rougher = scaler_rougher.transform(train_features_rougher)
train_features_rougher = pd.DataFrame(train_features_rougher, columns = train_col_rougher)

test_features_rougher = scaler_rougher.transform(test_features_rougher)
test_features_rougher = pd.DataFrame(test_features_rougher, columns = test_col_rougher)

# %%
train_features_final = train_features_final.drop(columns=['date'], axis=1)

# %%
test_features_final = test_features_final.drop(columns=['date'], axis=1)

# %%
# проведем масштабирование признаков финального этапа

scaler_final = StandardScaler()
scaler_final.fit(train_features_final)

train_col_final = train_features_final.columns
test_col_final = test_features_final.columns

train_features_final = scaler_final.transform(train_features_final)
train_features_final = pd.DataFrame(train_features_final, columns = train_col_final)

test_features_final = scaler_final.transform(test_features_final)
test_features_final = pd.DataFrame(test_features_final, columns = test_col_final)

# %% [markdown]
# #### Обучим модели

# %% [markdown]
# - **Linear Regression**

# %%
lin_reg = LinearRegression()
model_smape(lin_reg)

# %% [markdown]
# - **Decision Tree Regressor**

# %%
decision_tree_model = DecisionTreeRegressor()
model_smape(decision_tree_model)

# %%
# parameters_dt = {
#     'max_depth': [1, 2, 3, 4, 5, 10, 50, 100],
#     'splitter': ['best', 'random'],
#     'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson']
# }
# decision_tree_model = DecisionTreeRegressor()
# grid = GridSearchCV(decision_tree_model, param_grid=parameters_dt)
# best_decision_tree_model_rougher = grid.fit(train_features_rougher, train_target_rougher)

# %%
# model_smape(best_decision_tree_model_rougher)

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> To improve:<a class="tocSkip"> </h2>
#
# <b></b>
#
# Вместо закомментирования кода можно было прописать у GridSearchCV параметр scoring.

# %% [markdown]
# - **Random Forest Regressor**

# %%
random_forest_model = RandomForestRegressor()
model_smape(random_forest_model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/f0/6n5cj1pd2td3sgkgfsl766lr0000gn/T/ipykernel_90315/1300467049.py in <module>
#       1 random_forest_model = RandomForestRegressor()
# ----> 2 model_smape(random_forest_model)
#
# NameError: name 'model_smape' is not defined

# %%
# parameters_rf = {
#     'n_estimators': [10, 20, 31],
#     'criterion': ['squared_error', 'absolute_error', 'poisson'],
#     'max_depth': [7, 10, 30]
# }
# random_forest_model = RandomForestRegressor()
# grid = GridSearchCV(random_forest_model, param_grid=parameters_rf)
# best_random_forest_model_rougher = grid.fit(train_features_rougher, train_target_rougher)

# %%
# model_smape(best_random_forest_model_rougher)

# %% [markdown]
# - **DummyRegressor**

# %%
from sklearn.dummy import DummyRegressor

# %%
model_dummy_regressor = DummyRegressor()
model_smape(model_dummy_regressor)

# %%
print('sMAPE для линейной регрессии:')
model_smape(lin_reg)
print()

# %%
print('sMAPE для дерева решений:')
model_smape(decision_tree_model)
print()

# %%
print('sMAPE для случайного леса:')
model_smape(random_forest_model)
print()

# %%
print('sMAPE для dummy regressor:')
model_smape(model_dummy_regressor)

# %% [markdown]
# # Вывод
# **Случайный лес имеет наилучшую среднюю оценку качества, но она всего лишь немного лучше нежели если просто все заполнить средними значениями (Dummy). Настроим параметры случайного леса.**

# %%
# %%time 

best_smape = 10
best_est = 0
best_depth = 0
best_crit = None
best_model = None

for est in range(10, 51, 10):
    for depth in range (1, 20):
        for crit in {'squared_error', 'absolute_error', 'poisson'}:
            model = RandomForestRegressor(n_estimators=est, max_depth=depth, criterion=crit)
            smape_rougher = cross_valid(model, train_features_rougher, train_target_rougher)
            smape_final = cross_valid(model, train_features_final, train_target_final)
            smape_end = 0.25 * smape_rougher + 0.75 * smape_final
            if smape_end < best_smape:
                best_smape = smape_end
                best_est = est
                best_depth = depth
                best_crit = crit
                best_model = model
print('Наилучшая модель с sMAPE, равным {}, получена для случайного леса \
с количеством деревьев {}, глубиной {} и criterion {}'.format(best_smape, best_est, best_depth, best_crit))

# %% [markdown]
# # Вывод
# **Наилучшей моделью для предсказания двух целевых показателей является случайный лес со следующими параметрами:**
# - количество деревьев 20,
# - глубиной дерева 1,
# - criterion 'poisson'
#
# ***В качестве метрики качества выбрана sMAPE и при наилучшей модели она равна 5.535.***

# %% [markdown]
# #### Обучим модель и выполним предсказания на тестовых данных

# %%
best_model.fit(test_features_rougher, test_target_rougher)
best_model.predict(test_features_rougher)

# %%
best_model.fit(test_features_final, test_target_final)
best_model.predict(test_features_final)

# %% [markdown]
# #### Определим, какие из признаков больше всего влияют на целевые признаки

# %%
import seaborn as sp

# %%
type(best_model.feature_importances_)

# %%
importance = best_model.feature_importances_
indices = np.argsort(importance)

fig, ax = plt.subplots(figsize=(15, 25))
ax.barh(range(len(importance)), importance[indices])
ax.set_yticks(range(len(importance)))
_ = ax.set_yticklabels(np.array(train_features_final.columns)[indices])

fig, ax = plt.subplots(figsize=(15, 25))
ax.barh(range(len(importance)), importance[indices])
ax.set_yticks(range(len(importance)))
_ = ax.set_yticklabels(np.array(test_features_final.columns)[indices])

# %% [markdown]
# # Финальные выводы
#
# - Подготовлена функция расчета sMAPE.
# - Подготовлены обучающие и целевые признаки.
# - Обучающие признаки приведены к единой размерности.
# - Подготовлена автоматизированная функция поиска наилучшего sMAPE с помощью кросс-валидации.
# - **Наилучшей моделью оказался _случайный лес_ с 20 деревьями, глубиной 1, criterion': 'poisson'.**
# - Финальная sMAPE для данной модели на тестовой выборке составила =  5.535
#
# Наиболее влияют на целевые признаки следующие признаки:
#
#
# - размер частиц сырья на этапе флотации;
# - вторичная очистка концентрата, характеризующая текущее состояние этапа.

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [ ]  Весь код выполняется без ошибок
# - [ ]  Ячейки с кодом расположены в порядке выполнения
# - [ ]  Выполнен шаг 1: данные подготовлены
#     - [ ]  Проверена формула вычисления эффективности обогащения
#     - [ ]  Проанализированы признаки, недоступные в тестовой выборке
#     - [ ]  Проведена предобработка данных
# - [ ]  Выполнен шаг 2: данные проанализированы
#     - [ ]  Исследовано изменение концентрации элементов на каждом этапе
#     - [ ]  Проанализированы распределения размеров гранул на обучающей и тестовой выборках
#     - [ ]  Исследованы суммарные концентрации
# - [ ]  Выполнен шаг 3: построена модель прогнозирования
#     - [ ]  Написана функция для вычисления итогового *sMAPE*
#     - [ ]  Обучено и проверено несколько моделей
#     - [ ]  Выбрана лучшая модель, её качество проверено на тестовой выборке

# %% [markdown]
# ## Thank you!

# %% [markdown]
# ```
# Thank you for going through this projet.
# Your comments are more then welcome to ybezginova2021@gmail.com
#
# Best wishes,
#
# Yulia
#
# ```
